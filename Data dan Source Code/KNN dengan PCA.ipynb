# %%
# Import libraries
import math
import operator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

df = pd.read_csv("data baru 50.csv")
df = shuffle(df, random_state=1)
df.head()
# Out:
#       no  playlist  danceability  energy  key  loudness  mode  speechiness  \
# 681  682        13         0.590   0.737    1  0.878575     1       0.0384
# 626  627        12         0.589   0.797    1  0.889288     1       0.1500
# 329  330         6         0.816   0.579    1  0.872461     1       0.0867
# 620  621        12         0.500   0.847    1  0.922302     1       0.0417
# 399  400         7         0.411   0.449    1  0.618288     0       0.0318
#
#      acousticness  instrumentalness  liveness  valence     tempo  duration_ms
# 681       0.40400          0.000000    0.1080    0.877  0.614633            1
# 626       0.02890          0.000004    0.3830    0.232  0.473754            1
# 329       0.20300          0.000000    0.1270    0.430  0.555058            1
# 620       0.00125          0.000000    0.0875    0.716  0.582266            1
# 399       0.54800          0.609000    0.0814    0.579  0.665637            1

# %%
data = df.drop(columns=['no', 'playlist'])
data.head()
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 681         0.590   0.737    1  0.878575     1       0.0384       0.40400
# 626         0.589   0.797    1  0.889288     1       0.1500       0.02890
# 329         0.816   0.579    1  0.872461     1       0.0867       0.20300
# 620         0.500   0.847    1  0.922302     1       0.0417       0.00125
# 399         0.411   0.449    1  0.618288     0       0.0318       0.54800
#
#      instrumentalness  liveness  valence     tempo  duration_ms
# 681          0.000000    0.1080    0.877  0.614633            1
# 626          0.000004    0.3830    0.232  0.473754            1
# 329          0.000000    0.1270    0.430  0.555058            1
# 620          0.000000    0.0875    0.716  0.582266            1
# 399          0.609000    0.0814    0.579  0.665637            1

# %%
target = df.playlist
target.head()
# Out:
# 681    13
# 626    12
# 329     6
# 620    12
# 399     7
# Name: playlist, dtype: int64

# %%
min_max_scaler = MinMaxScaler()

# %%
def euclideanDistance(instance1, instance2, length):
    distance = 0
    for x in range(length):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)

def getNeighbors(trainingSet, testInstance, trainingTarget, k):
    distances = []
    length = len(testInstance)-1
    for x in range(len(trainingSet)):
        dist = euclideanDistance(testInstance, trainingSet[x], length)
        distances.append((trainingTarget[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors

def getResponse(neighbors):
    max = 0
    result = 0
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    for key, value in classVotes.items():
        if(value > max):
            result = key
            max = value
    return result
    
def getAccuracy(testSet, predictions):
    correct = 0
    for x in range(len(testSet)):
        if testSet[x][-1] == predictions[x]:
            correct += 1
    return (correct/float(len(testSet))) * 100.0

def cm_analysis(y_true, y_pred, labels, ymap=None, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)

# %%
# Proses KNN
X = data.values
y = target.values
kf = KFold(n_splits=10)
pca = PCA(n_components=3)
k = 49

# KNN
fold = 0
accuracy_total = 0

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    X_train_scale = min_max_scaler.fit_transform(X_train)
    X_test_scale = min_max_scaler.transform(X_test)
    
    pca.fit(X_train_scale)
    X_train_pca = pca.fit_transform(X_train_scale)
    X_test_pca = pca.fit_transform(X_test_scale)
    
    index = np.hstack((train_index, test_index))
    index = np.reshape(index, (len(index), 1))
    X_pca = np.vstack((X_train_pca, X_test_pca))
    Y_pca = np.hstack((y_train, y_test))
    Y_pca = np.reshape(Y_pca, (len(Y_pca), 1))
    data_pca = np.hstack((index, X_pca, Y_pca))
    
    predictions=[]
    
    fold += 1
    np.savetxt('Klasifikasi Data/KNN MKNN dengan PCA/Data PCA KNN Fold ' + str(fold) + '.csv', data_pca, delimiter=",")
    print('KFold ' + str(fold))
    print('======================================')
          
    for i in range(len(X_test_pca)):
        neighbors = getNeighbors(X_train_pca, X_test_pca[i], y_train, k)
        result = getResponse(neighbors)
        predictions.append(result)
        
        print('> ' + str(i + 1) + ' predicted = ' + repr(result) + ', actual = ' + repr(y_test[i]))
        
    accuracy = accuracy_score(y_test, predictions)
    accuracy_total += accuracy
    cm_analysis(y_test, predictions, target.unique().sort(), ymap=None, figsize=(10,10))
    plt.savefig('Klasifikasi Data/Gambar Confussion Matrix dengan PCA/Confussion Matrix KNN Fold ' + str(fold) + '.jpg')
    
    print('---------------------------------------')
    print('KFold ' + str(fold) + ', Accuracy ' + str(accuracy))
    print('Klasifikasi Data/KNN MKNN dengan PCA/Data PCA KNN Fold ' + str(fold) + '.csv')
    print('\n')

print('======================================')
print('Average Accuracy = ' + str(accuracy_total/fold))
print('======================================')
print('\n')
# Out:
#  4, actual = 3
# > 55 predicted = 6, actual = 10
# > 56 predicted = 4, actual = 12
# > 57 predicted = 4, actual = 2
# > 58 predicted = 11, actual = 9
# > 59 predicted = 8, actual = 2
# > 60 predicted = 8, actual = 5
# > 61 predicted = 12, actual = 13
# > 62 predicted = 7, actual = 0
# > 63 predicted = 0, actual = 10
# > 64 predicted = 7, actual = 11
# > 65 predicted = 11, actual = 13
# > 66 predicted = 8, actual = 12
# > 67 predicted = 11, actual = 8
# > 68 predicted = 11, actual = 2
# > 69 predicted = 0, actual = 1
# > 70 predicted = 4, actual = 4
# ---------------------------------------
# KFold 2, Accuracy 0.04285714285714286
# Klasifikasi Data/KNN MKNN dengan PCA/Data PCA KNN Fold 2.csv
#
#
# KFold 3
# ======================================
# > 1 predicted = 7, actual = 6
# > 2 predicted = 7, actual = 11
# > 3 predicted = 5, actual = 2
# > 4 predicted = 2, actual = 0
# > 5 predicted = 8, actual = 12
# > 6 predicted = 12, actual = 6
# > 7 predicted = 1, actual = 7
# > 8 predicted = 10, actual = 0
# > 9 predicted = 2, actual = 3
# > 10 predicted = 3, actual = 3
# > 11 predicted = 8, actual = 6
# > 12 predicted = 5, actual = 0
# > 13 predicted = 1, actual = 1
# > 14 predicted = 4, actual = 13
# > 15 predicted = 12, actual = 9
# > 16 predicted = 12, actual = 2
# > 17 predicted = 4, actual = 7
# > 18 predicted = 8, actual = 9
# > 19 predicted = 12, actual = 6
# > 20 predicted = 12, actual = 11
# > 21 predicted = 11, actual = 11
# > 22 predicted = 0, actual = 2
# > 23 predicted = 8, actual = 0
# > 24 predicted = 0, actual = 0
# > 25 predicted = 1, actual = 7
# > 26 predicted = 2, actual = 4
# > 27 predicted = 4, actual = 6
# > 28 predicted = 4, actual = 9
# > 29 predicted = 8, actual = 4
# > 30 predicted = 7, actual = 12
# > 31 predicted = 3, actual = 6
# > 32 predicted = 0, actual = 2
# > 33 predicted = 8, actual = 4
# > 34 predicted = 4, actual = 12
# > 35 predicted = 1, actual = 1
# > 36 predicted = 4, actual = 5
# > 37 predicted = 8, actual = 6
# > 38 predicted = 13, actual = 11
# > 39 predicted = 12, actual = 12
# > 40 predicted = 8, actual = 4
# > 41 predicted = 1, actual = 1
# > 42 predicted = 7, actual = 8
# > 43 predicted = 5, actual = 13
# > 44 predicted = 3, actual = 5
# > 45 predicted = 7, actual = 2
# > 46 predicted = 8, actual = 12
# > 47 predicted = 4, actual = 8
# > 48 predicted = 5, actual = 10
# > 49 predicted = 5, actual = 5
# > 50 predicted = 1, actual = 7
# > 51 predicted = 0, actual = 9
# > 52 predicted = 7, actual = 13
# > 53 predicted = 1, actual = 1
# > 54 predicted = 10, actual = 10
# > 55 predicted = 10, actual = 11
# > 56 predicted = 2, actual = 0
# > 57 predicted = 11, actual = 9
# > 58 predicted = 8, actual = 8
# > 59 predicted = 3, actual = 9
# > 60 predicted = 4, actual = 8
# > 61 predicted = 7, actual = 10
# > 62 predicted = 8, actual = 9
# > 63 predicted = 3, actual = 8
# > 64 predicted = 8, actual = 9
# > 65 predicted = 11, actual = 6
# > 66 predicted = 5, actual = 3
# > 67 predicted = 4, actual = 8
# > 68 predicted = 8, actual = 12
# > 69 predicted = 12, actual = 11
# > 70 predicted = 0, actual = 2
# ---------------------------------------
# KFold 3, Accuracy 0.15714285714285714
# Klasifikasi Data/KNN MKNN dengan PCA/Data PCA KNN Fold 3.csv
#
#
# KFold 4
# ======================================
# > 1 predicted = 4, actual = 5
# > 2 predicted = 4, actual = 2
# > 3 predicted = 4, actual = 4
# > 4 predicted = 5, actual = 10
# > 5 predicted = 11, actual = 3
# > 6 predicted = 8, actual = 13
# > 7 predicted = 10, actual = 1
# > 8 predicted = 5, actual = 6
# > 9 predicted = 13, actual = 6
# > 10 predicted = 5, actual = 8
# > 11 predicted = 13, actual = 3
# > 12 predicted = 0, actual = 0
# > 13 predicted = 4, actual = 13
# > 14 predicted = 4, actual = 0
# > 15 predicted = 4, actual = 8
# > 16 predicted = 4, actual = 8
# > 17 predicted = 10, actual = 7
# > 18 predicted = 4, actual = 12
# > 19 predicted = 4, actual = 3
# > 20 predicted = 10, actual = 7
# > 21 predicted = 5, actual = 6
# > 22 predicted = 1, actual = 7
# > 23 predicted = 0, actual = 13
# > 24 predicted = 4, actual = 8
# > 25 predicted = 13, actual = 8
# > 26 predicted = 13, actual = 12
# > 27 predicted = 13, actual = 4
# > 28 predicted = 13, actual = 3
# > 29 predicted = 13, actual = 0
# > 30 predicted = 10, actual = 7
# > 31 predicted = 4, actual = 10
# > 32 predicted = 1, actual = 7
# > 33 predicted = 0, actual = 0
# > 34 predicted = 11, actual = 13
# > 35 predicted = 7, actual = 7
# > 36 predicted = 0, actual = 7
# > 37 predicted = 0, actual = 8
# > 38 predicted = 12, actual = 0
# > 39 predicted = 5, actual = 5
# > 40 predicted = 10, actual = 11
# > 41 predicted = 5, actual = 5
# > 42 predicted = 10, actual = 7
# > 43 predicted = 13, actual = 11
# > 44 predicted = 5, actual = 3
# > 45 predicted = 10, actual = 1
# > 46 predicted = 4, actual = 2
# > 47 predicted = 10, actual = 0
# > 48 predicted = 10, actual = 0
# > 49 predicted = 7, actual = 0
# > 50 predicted = 0, actual = 8
# > 51 predicted = 10, actual = 1
# > 52 predicted = 12, actual = 10
# > 53 predicted = 5, actual = 4
# > 54 predicted = 5, actual = 6
# > 55 predicted = 4, actual = 12
# > 56 predicted = 13, actual = 9
# > 57 predicted = 11, actual = 5
# > 58 predicted = 4, actual = 6
# > 59 predicted = 4, actual = 8
# > 60 predicted = 13, actual = 3
# > 61 predicted = 5, actual = 7
# > 62 predicted = 13, actual = 12
# > 63 predicted = 4, actual = 5
# > 64 predicted = 0, actual = 10
# > 65 predicted = 0, actual = 9
# > 66 predicted = 5, actual = 4
# > 67 predicted = 12, actual = 13
# > 68 predicted = 10, actual = 1
# > 69 predicted = 0, actual = 10
# > 70 predicted = 10, actual = 0
# ---------------------------------------
# KFold 4, Accuracy 0.08571428571428572
# Klasifikasi Data/KNN MKNN dengan PCA/Data PCA KNN Fold 4.csv
#
#
# KFold 5
# ======================================
# > 1 predicted = 0, actual = 2
# > 2 predicted = 11, actual = 9
# > 3 predicted = 4, actual = 11
# > 4 predicted = 0, actual = 5
# > 5 predicted = 13, actual = 12
# > 6 predicted = 11, actual = 8
# > 7 predicted = 0, actual = 7
# > 8 predicted = 4, actual = 3
# > 9 predicted = 5, actual = 8
# > 10 predicted = 1, actual = 7
# > 11 predicted = 5, actual = 6
# > 12 predicted = 0, actual = 10
# > 13 predicted = 13, actual = 7
# > 14 predicted = 13, actual = 8
# > 15 predicted = 4, actual = 3
# > 16 predicted = 11, actual = 13
# > 17 predicted = 13, actual = 8
# > 18 predicted = 11, actual = 13
# > 19 predicted = 5, actual = 10
# > 20 predicted = 11, actual = 2
# > 21 predicted = 1, actual = 1
# > 22 predicted = 11, actual = 9
# > 23 predicted = 11, actual = 11
# > 24 predicted = 11, actual = 6
# > 25 predicted = 1, actual = 1
# > 26 predicted = 13, actual = 7
# > 27 predicted = 11, actual = 2
# > 28 predicted = 0, actual = 3
# > 29 predicted = 11, actual = 2
# > 30 predicted = 11, actual = 10
# > 31 predicted = 4, actual = 8
# > 32 predicted = 0, actual = 8
# > 33 predicted = 0, actual = 10
# > 34 predicted = 11, actual = 2
# > 35 predicted = 11, actual = 13
# > 36 predicted = 5, actual = 0
# > 37 predicted = 0, actual = 5
# > 38 predicted = 0, actual = 10
# > 39 predicted = 0, actual = 4
# > 40 predicted = 13, actual = 8
# > 41 predicted = 10, actual = 1
# > 42 predicted = 13, actual = 4
# > 43 predicted = 13, actual = 12
# > 44 predicted = 12, actual = 11
# > 45 predicted = 2, actual = 4
# > 46 predicted = 12, actual = 9
# > 47 predicted = 4, actual = 5
# > 48 predicted = 0, actual = 10
# > 49 predicted = 10, actual = 0
# > 50 predicted = 11, actual = 13
# > 51 predicted = 0, actual = 4
# > 52 predicted = 11, actual = 0
# > 53 predicted = 0, actual = 13
# > 54 predicted = 13, actual = 4
# > 55 predicted = 10, actual = 0
# > 56 predicted = 9, actual = 3
# > 57 predicted = 10, actual = 13
# > 58 predicted = 11, actual = 5
# > 59 predicted = 0, actual = 10
# > 60 predicted = 1, actual = 13
# > 61 predicted = 10, actual = 10
# > 62 predicted = 13, actual = 6
# > 63 predicted = 10, actual = 5
# > 64 predicted = 11, actual = 12
# > 65 predicted = 5, actual = 10
# > 66 predicted = 11, actual = 10
# > 67 predicted = 0, actual = 7
# > 68 predicted = 7, actual = 1
# > 69 predicted = 2, actual = 4
# > 70 predicted = 10, actual = 5
# ---------------------------------------
# KFold 5, Accuracy 0.05714285714285714
# Klasifikasi Data/KNN MKNN dengan PCA/Data PCA KNN Fold 5.csv
#
#
# KFold 6
# ======================================
# > 1 predicted = 10, actual = 6
# > 2 predicted = 12, actual = 5
# > 3 predicted = 12, actual = 8
# > 4 predicted = 10, actual = 2
# > 5 predicted = 10, actual = 2
# > 6 predicted = 10, actual = 13
# > 7 predicted = 10, actual = 13
# > 8 predicted = 6, actual = 8
# > 9 predicted = 10, actual = 0
# > 10 predicted = 6, actual = 9
# > 11 predicted = 12, actual = 7
# > 12 predicted = 10, actual = 4
# > 13 predicted = 6, actual = 4
# > 14 predicted = 8, actual = 4
# > 15 predicted = 6, actual = 4
# > 16 predicted = 8, actual = 8
# > 17 predicted = 10, actual = 9
# > 18 predicted = 7, actual = 10
# > 19 predicted = 1, actual = 7
# > 20 predicted = 8, actual = 4
# > 21 predicted = 10, actual = 2
# > 22 predicted = 6, actual = 11
# > 23 predicted = 6, actual = 3
# > 24 predicted = 10, actual = 12
# > 25 predicted = 10, actual = 11
# > 26 predicted = 10, actual = 11
# > 27 predicted = 6, actual = 4
# > 28 predicted = 1, actual = 1
# > 29 predicted = 10, actual = 9
# > 30 predicted = 10, actual = 5
# > 31 predicted = 6, actual = 11
# > 32 predicted = 1, actual = 1
# > 33 predicted = 6, actual = 8
# > 34 predicted = 2, actual = 7
# > 35 predicted = 1, actual = 1
# > 36 predicted = 10, actual = 9
# > 37 predicted = 8, actual = 12
# > 38 predicted = 1, actual = 7
# > 39 predicted = 10, actual = 0
# > 40 predicted = 10, actual = 6
# > 41 predicted = 10, actual = 11
# > 42 predicted = 8, actual = 2
# > 43 predicted = 6, actual = 11
# > 44 predicted = 12, actual = 0
# > 45 predicted = 6, actual = 8
# > 46 predicted = 10, actual = 0
# > 47 predicted = 1, actual = 1
# > 48 predicted = 6, actual = 6
# > 49 predicted = 1, actual = 1
# > 50 predicted = 10, actual = 3
# > 51 predicted = 10, actual = 3
# > 52 predicted = 7, actual = 13
# > 53 predicted = 10, actual = 11
# > 54 predicted = 12, actual = 10
# > 55 predicted = 10, actual = 9
# > 56 predicted = 1, actual = 1
# > 57 predicted = 10, actual = 10
# > 58 predicted = 10, actual = 7
# > 59 predicted = 6, actual = 12
# > 60 predicted = 6, actual = 2
# > 61 predicted = 5, actual = 13
# > 62 predicted = 6, actual = 8
# > 63 predicted = 10, actual = 6
# > 64 predicted = 10, actual = 7
# > 65 predicted = 10, actual = 0
# > 66 predicted = 8, actual = 12
# > 67 predicted = 12, actual = 13
# > 68 predicted = 10, actual = 13
# > 69 predicted = 12, actual = 10
# > 70 predicted = 6, actual = 11
# ---------------------------------------
# KFold 6, Accuracy 0.12857142857142856
# Klasifikasi Data/KNN MKNN dengan PCA/Data PCA KNN Fold 6.csv
#
#
# KFold 7
# ======================================
# > 1 predicted = 10, actual = 4
# > 2 predicted = 12, actual = 2
# > 3 predicted = 13, actual = 11
# > 4 predicted = 12, actual = 6
# > 5 predicted = 12, actual = 8
# > 6 predicted = 13, actual = 2
# > 7 predicted = 13, actual = 12
# > 8 predicted = 1, actual = 0
# > 9 predicted = 11, actual = 13
# > 10 predicted = 1, actual = 1
# > 11 predicted = 13, actual = 8
# > 12 predicted = 8, actual = 4
# > 13 predicted = 13, actual = 6
# > 14 predicted = 2, actual = 2
# > 15 predicted = 10, actual = 7
# > 16 predicted = 10, actual = 3
# > 17 predicted = 2, actual = 11
# > 18 predicted = 5, actual = 3
# > 19 predicted = 0, actual = 5
# > 20 predicted = 12, actual = 8
# > 21 predicted = 11, actual = 12
# > 22 predicted = 2, actual = 2
# > 23 predicted = 13, actual = 2
# > 24 predicted = 10, actual = 12
# > 25 predicted = 1, actual = 1
# > 26 predicted = 8, actual = 4
# > 27 predicted = 13, actual = 2
# > 28 predicted = 13, actual = 5
# > 29 predicted = 5, actual = 5
# > 30 predicted = 13, actual = 5
# > 31 predicted = 11, actual = 6
# > 32 predicted = 13, actual = 5
# > 33 predicted = 11, actual = 3
# > 34 predicted = 11, actual = 2
# > 35 predicted = 12, actual = 6
# > 36 predicted = 10, actual = 8
# > 37 predicted = 2, actual = 13
# > 38 predicted = 13, actual = 12
# > 39 predicted = 10, actual = 4
# > 40 predicted = 10, actual = 4
# > 41 predicted = 5, actual = 3
# > 42 predicted = 12, actual = 6
# > 43 predicted = 3, actual = 4
# > 44 predicted = 13, actual = 9
# > 45 predicted = 0, actual = 10
# > 46 predicted = 0, actual = 5
# > 47 predicted = 13, actual = 3
# > 48 predicted = 10, actual = 3
# > 49 predicted = 2, actual = 9
# > 50 predicted = 10, actual = 3
# > 51 predicted = 11, actual = 3
# > 52 predicted = 11, actual = 11
# > 53 predicted = 10, actual = 4
# > 54 predicted = 13, actual = 3
# > 55 predicted = 10, actual = 6
# > 56 predicted = 10, actual = 6
# > 57 predicted = 0, actual = 2
# > 58 predicted = 13, actual = 3
# > 59 predicted = 11, actual = 4
# > 60 predicted = 5, actual = 4
# > 61 predicted = 0, actual = 3
# > 62 predicted = 2, actual = 4
# > 63 predicted = 0, actual = 5
# > 64 predicted = 2, actual = 11
# > 65 predicted = 11, actual = 12
# > 66 predicted = 10, actual = 10
# > 67 predicted = 5, actual = 10
# > 68 predicted = 1, actual = 1
# > 69 predicted = 10, actual = 7
# > 70 predicted = 5, actual = 11
# ---------------------------------------
# KFold 7, Accuracy 0.11428571428571428
# Klasifikasi Data/KNN MKNN dengan PCA/Data PCA KNN Fold 7.csv
#
#
# KFold 8
# ======================================
# > 1 predicted = 11, actual = 3
# > 2 predicted = 11, actual = 12
# > 3 predicted = 1, actual = 1
# > 4 predicted = 13, actual = 4
# > 5 predicted = 10, actual = 10
# > 6 predicted = 10, actual = 5
# > 7 predicted = 10, actual = 10
# > 8 predicted = 0, actual = 8
# > 9 predicted = 0, actual = 10
# > 10 predicted = 13, actual = 4
# > 11 predicted = 4, actual = 2
# > 12 predicted = 11, actual = 5
# > 13 predicted = 13, actual = 12
# > 14 predicted = 10, actual = 8
# > 15 predicted = 1, actual = 7
# > 16 predicted = 4, actual = 13
# > 17 predicted = 1, actual = 1
# > 18 predicted = 11, actual = 4
# > 19 predicted = 0, actual = 7
# > 20 predicted = 10, actual = 13
# > 21 predicted = 2, actual = 13
# > 22 predicted = 12, actual = 3
# > 23 predicted = 10, actual = 5
# > 24 predicted = 13, actual = 9
# > 25 predicted = 10, actual = 9
# > 26 predicted = 10, actual = 5
# > 27 predicted = 0, actual = 0
# > 28 predicted = 10, actual = 2
# > 29 predicted = 0, actual = 0
# > 30 predicted = 2, actual = 4
# > 31 predicted = 11, actual = 3
# > 32 predicted = 0, actual = 10
# > 33 predicted = 10, actual = 0
# > 34 predicted = 10, actual = 2
# > 35 predicted = 11, actual = 2
# > 36 predicted = 13, actual = 6
# > 37 predicted = 4, actual = 4
# > 38 predicted = 11, actual = 0
# > 39 predicted = 13, actual = 5
# > 40 predicted = 1, actual = 1
# > 41 predicted = 11, actual = 12
# > 42 predicted = 10, actual = 13
# > 43 predicted = 10, actual = 0
# > 44 predicted = 9, actual = 13
# > 45 predicted = 11, actual = 9
# > 46 predicted = 1, actual = 1
# > 47 predicted = 5, actual = 8
# > 48 predicted = 4, actual = 7
# > 49 predicted = 13, actual = 12
# > 50 predicted = 4, actual = 6
# > 51 predicted = 2, actual = 9
# > 52 predicted = 13, actual = 4
# > 53 predicted = 13, actual = 9
# > 54 predicted = 11, actual = 8
# > 55 predicted = 4, actual = 12
# > 56 predicted = 2, actual = 6
# > 57 predicted = 4, actual = 12
# > 58 predicted = 11, actual = 4
# > 59 predicted = 11, actual = 12
# > 60 predicted = 10, actual = 5
# > 61 predicted = 12, actual = 0
# > 62 predicted = 11, actual = 8
# > 63 predicted = 11, actual = 6
# > 64 predicted = 0, actual = 3
# > 65 predicted = 10, actual = 9
# > 66 predicted = 11, actual = 2
# > 67 predicted = 0, actual = 10
# > 68 predicted = 4, actual = 4
# > 69 predicted = 11, actual = 13
# > 70 predicted = 4, actual = 13
# ---------------------------------------
# KFold 8, Accuracy 0.14285714285714285
# Klasifikasi Data/KNN MKNN dengan PCA/Data PCA KNN Fold 8.csv
#
#
# KFold 9
# ======================================
# > 1 predicted = 11, actual = 12
# > 2 predicted = 1, actual = 10
# > 3 predicted = 13, actual = 11
# > 4 predicted = 7, actual = 4
# > 5 predicted = 11, actual = 8
# > 6 predicted = 11, actual = 6
# > 7 predicted = 4, actual = 3
# > 8 predicted = 13, actual = 11
# > 9 predicted = 11, actual = 11
# > 10 predicted = 1, actual = 9
# > 11 predicted = 7, actual = 5
# > 12 predicted = 7, actual = 0
# > 13 predicted = 13, actual = 3
# > 14 predicted = 13, actual = 8
# > 15 predicted = 13, actual = 12
# > 16 predicted = 11, actual = 11
# > 17 predicted = 13, actual = 3
# > 18 predicted = 13, actual = 6
# > 19 predicted = 4, actual = 3
# > 20 predicted = 7, actual = 9
# > 21 predicted = 4, actual = 12
# > 22 predicted = 11, actual = 5
# > 23 predicted = 12, actual = 9
# > 24 predicted = 11, actual = 2
# > 25 predicted = 11, actual = 6
# > 26 predicted = 7, actual = 11
# > 27 predicted = 13, actual = 9
# > 28 predicted = 11, actual = 11
# > 29 predicted = 13, actual = 3
# > 30 predicted = 4, actual = 2
# > 31 predicted = 12, actual = 8
# > 32 predicted = 4, actual = 9
# > 33 predicted = 4, actual = 3
# > 34 predicted = 13, actual = 12
# > 35 predicted = 7, actual = 0
# > 36 predicted = 11, actual = 5
# > 37 predicted = 12, actual = 1
# > 38 predicted = 11, actual = 4
# > 39 predicted = 13, actual = 13
# > 40 predicted = 13, actual = 11
# > 41 predicted = 1, actual = 10
# > 42 predicted = 11, actual = 13
# > 43 predicted = 7, actual = 10
# > 44 predicted = 11, actual = 13
# > 45 predicted = 11, actual = 6
# > 46 predicted = 4, actual = 1
# > 47 predicted = 7, actual = 1
# > 48 predicted = 4, actual = 5
# > 49 predicted = 7, actual = 2
# > 50 predicted = 13, actual = 13
# > 51 predicted = 13, actual = 10
# > 52 predicted = 0, actual = 13
# > 53 predicted = 13, actual = 9
# > 54 predicted = 11, actual = 11
# > 55 predicted = 13, actual = 9
# > 56 predicted = 4, actual = 5
# > 57 predicted = 13, actual = 7
# > 58 predicted = 11, actual = 6
# > 59 predicted = 4, actual = 3
# > 60 predicted = 13, actual = 6
# > 61 predicted = 13, actual = 3
# > 62 predicted = 13, actual = 11
# > 63 predicted = 4, actual = 6
# > 64 predicted = 13, actual = 4
# > 65 predicted = 4, actual = 1
# > 66 predicted = 13, actual = 12
# > 67 predicted = 4, actual = 8
# > 68 predicted = 11, actual = 5
# > 69 predicted = 13, actual = 3
# > 70 predicted = 13, actual = 11
# ---------------------------------------
# KFold 9, Accuracy 0.08571428571428572
# Klasifikasi Data/KNN MKNN dengan PCA/Data PCA KNN Fold 9.csv
#
#
# KFold 10
# ======================================
# > 1 predicted = 0, actual = 13
# > 2 predicted = 4, actual = 3
# > 3 predicted = 7, actual = 7
# > 4 predicted = 0, actual = 7
# > 5 predicted = 0, actual = 5
# > 6 predicted = 11, actual = 2
# > 7 predicted = 4, actual = 0
# > 8 predicted = 4, actual = 12
# > 9 predicted = 4, actual = 5
# > 10 predicted = 4, actual = 9
# > 11 predicted = 7, actual = 7
# > 12 predicted = 4, actual = 0
# > 13 predicted = 0, actual = 3
# > 14 predicted = 7, actual = 1
# > 15 predicted = 10, actual = 0
# > 16 predicted = 5, actual = 9
# > 17 predicted = 4, actual = 5
# > 18 predicted = 13, actual = 12
# > 19 predicted = 6, actual = 6
# > 20 predicted = 0, actual = 0
# > 21 predicted = 13, actual = 11
# > 22 predicted = 10, actual = 0
# > 23 predicted = 13, actual = 9
# > 24 predicted = 4, actual = 10
# > 25 predicted = 0, actual = 13
# > 26 predicted = 0, actual = 11
# > 27 predicted = 0, actual = 9
# > 28 predicted = 4, actual = 7
# > 29 predicted = 1, actual = 1
# > 30 predicted = 0, actual = 10
# > 31 predicted = 13, actual = 9
# > 32 predicted = 4, actual = 12
# > 33 predicted = 13, actual = 8
# > 34 predicted = 4, actual = 12
# > 35 predicted = 13, actual = 13
# > 36 predicted = 4, actual = 5
# > 37 predicted = 6, actual = 4
# > 38 predicted = 0, actual = 6
# > 39 predicted = 10, actual = 10
# > 40 predicted = 4, actual = 6
# > 41 predicted = 8, actual = 10
# > 42 predicted = 0, actual = 6
# > 43 predicted = 10, actual = 0
# > 44 predicted = 0, actual = 7
# > 45 predicted = 4, actual = 2
# > 46 predicted = 1, actual = 1
# > 47 predicted = 4, actual = 9
# > 48 predicted = 0, actual = 10
# > 49 predicted = 13, actual = 4
# > 50 predicted = 0, actual = 11
# > 51 predicted = 13, actual = 11
# > 52 predicted = 0, actual = 7
# > 53 predicted = 4, actual = 13
# > 54 predicted = 13, actual = 9
# > 55 predicted = 4, actual = 5
# > 56 predicted = 4, actual = 9
# > 57 predicted = 11, actual = 7
# > 58 predicted = 4, actual = 5
# > 59 predicted = 4, actual = 5
# > 60 predicted = 13, actual = 3
# > 61 predicted = 11, actual = 5
# > 62 predicted = 1, actual = 7
# > 63 predicted = 0, actual = 10
# > 64 predicted = 13, actual = 11
# > 65 predicted = 4, actual = 2
# > 66 predicted = 6, actual = 2
# > 67 predicted = 4, actual = 12
# > 68 predicted = 1, actual = 1
# > 69 predicted = 11, actual = 4
# > 70 predicted = 4, actual = 0
# ---------------------------------------
# KFold 10, Accuracy 0.12857142857142856
# Klasifikasi Data/KNN MKNN dengan PCA/Data PCA KNN Fold 10.csv
#
#
# ======================================
# Average Accuracy = 0.10428571428571427
# ======================================
