# %%
# Import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt # for Data visualization
from sklearn.preprocessing import minmax_scale
df = pd.read_csv("D:\Codingan\Visual Studio Code\Spotify\Spotify Analysis 1\data fix baru 50.csv")

# %%
df
# Out:
#       no  playlist  danceability  energy  key  loudness  mode  speechiness  \
# 0      1         0         0.598   0.735    1  0.745268     1       0.0973
# 1      2         0         0.692   0.493    1  0.777698     0       0.0325
# 2      3         0         0.821   0.376    0  0.672435     1       0.0487
# 3      4         0         0.661   0.342    1  0.599628     0       0.0430
# 4      5         0         0.542   0.588    1  0.788171     1       0.0665
# ..   ...       ...           ...     ...  ...       ...   ...          ...
# 695  696        13         0.691   0.581    1  0.825864     1       0.0650
# 696  697        13         0.559   0.537    1  0.850744     0       0.0330
# 697  698        13         0.257   0.338    1  0.691574     1       0.0357
# 698  699        13         0.617   0.879    0  0.833466     0       0.0455
# 699  700        13         0.773   0.418    1  0.831313     1       0.0423
#
# ...

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.distplot(df['tempo'],kde=False)
plt.xlabel("Tempo", fontsize=20)
fig.savefig("D:\Codingan\Visual Studio Code\Spotify\Spotify Analysis 1\Klasifikasi Data\Histogram\Tempo_new.png", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.distplot(df['loudness'],kde=False)
plt.xlabel("Loudness", fontsize=20)
fig.savefig("D:\Codingan\Visual Studio Code\Spotify\Spotify Analysis 1\Klasifikasi Data\Histogram\Loudness_new.png", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.distplot(df['key'],kde=False)
plt.xlabel("Key", fontsize=20)
fig.savefig("D:\Codingan\Visual Studio Code\Spotify\Spotify Analysis 1\Klasifikasi Data\Histogram\key_new.png", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.distplot(df['duration_ms'],kde=False)
plt.xlabel("Duration_ms", fontsize=20)
fig.savefig("D:\Codingan\Visual Studio Code\Spotify\Spotify Analysis 1\Klasifikasi Data\Histogram\Duration_new.png", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.distplot(df['danceability'],kde=False)
plt.xlabel("Danceability", fontsize=20)
fig.savefig("D:\Codingan\Visual Studio Code\Spotify\Spotify Analysis 1\Klasifikasi Data\Histogram\Danceability_new.png", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.distplot(df['energy'],kde=False)
plt.xlabel("Energy", fontsize=20)
fig.savefig("D:\Codingan\Visual Studio Code\Spotify\Spotify Analysis 1\Klasifikasi Data\Histogram\Energy_new.png", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.distplot(df['mode'],kde=False)
plt.xlabel("Mode", fontsize=20)
fig.savefig("D:\Codingan\Visual Studio Code\Spotify\Spotify Analysis 1\Klasifikasi Data\Histogram\mode_new.png", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.distplot(df['speechiness'],kde=False)
plt.xlabel("Speechiness", fontsize=20)
fig.savefig("D:\Codingan\Visual Studio Code\Spotify\Spotify Analysis 1\Klasifikasi Data\Histogram\Speechiness_new.png", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.distplot(df['acousticness'],kde=False)
plt.xlabel("", fontsize=20)
fig.savefig("D:\Codingan\Visual Studio Code\Spotify\Spotify Analysis 1\Klasifikasi Data\Histogram\Acousticness_new.png", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.distplot(df['instrumentalness'],kde=False)
plt.xlabel("Instrumentalness", fontsize=20)
fig.savefig("D:\Codingan\Visual Studio Code\Spotify\Spotify Analysis 1\Klasifikasi Data\Histogram\Instrumentalness_new.png", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.distplot(df['liveness'],kde=False)
plt.xlabel("Liveness", fontsize=20)
fig.savefig("D:\Codingan\Visual Studio Code\Spotify\Spotify Analysis 1\Klasifikasi Data\Histogram\Liveness_new.png", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.distplot(df['valence'],kde=False)
plt.xlabel("Valence", fontsize=20)
fig.savefig("D:\Codingan\Visual Studio Code\Spotify\Spotify Analysis 1\Klasifikasi Data\Histogram\Valence_new.png", bbox_inches="tight")
