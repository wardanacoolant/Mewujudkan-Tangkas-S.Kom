# %%
import math
import operator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

df = pd.read_csv("C:/Users/pradn/AnacondaProjects/Spotify Analysis/data/Data Fix Genre.csv")
df = shuffle(df)
df.head()
# Out:
#       No  Playlist  danceability  energy  key  loudness  mode  speechiness  \
# 475  476         9         0.624   0.876    9    -3.374     1       0.1000
# 516  517        10         0.833   0.515   11    -5.000     0       0.0462
# 367  368         7         0.411   0.449    9   -15.659     0       0.0318
# 320  321         6         0.859   0.750    8    -8.325     0       0.3030
# 104  105         2         0.506   0.886   11    -3.225     1       0.0655
#
#      acousticness  instrumentalness  liveness  valence    tempo  duration_ms
# 475        0.0735           0.00000    0.3270    0.781   99.943       170827
# 516        0.3470           0.00156    0.1160    0.400   97.035       257333
# 367        0.5480           0.60900    0.0814    0.579  144.000       250000
# 320        0.0193           0.00000    0.0538    0.857   98.691       345717
# 104        0.0916           0.00000    0.0734    0.595  143.935       226867

# %%
data = df.drop(columns=['No', 'Playlist'])
data.head()
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 475         0.624   0.876    9    -3.374     1       0.1000        0.0735
# 516         0.833   0.515   11    -5.000     0       0.0462        0.3470
# 367         0.411   0.449    9   -15.659     0       0.0318        0.5480
# 320         0.859   0.750    8    -8.325     0       0.3030        0.0193
# 104         0.506   0.886   11    -3.225     1       0.0655        0.0916
#
#      instrumentalness  liveness  valence    tempo  duration_ms
# 475           0.00000    0.3270    0.781   99.943       170827
# 516           0.00156    0.1160    0.400   97.035       257333
# 367           0.60900    0.0814    0.579  144.000       250000
# 320           0.00000    0.0538    0.857   98.691       345717
# 104           0.00000    0.0734    0.595  143.935       226867

# %%
target = df.Playlist
target.head()
# Out:
# 475     9
# 516    10
# 367     7
# 320     6
# 104     2
# Name: Playlist, dtype: int64

# %%
min_max_scaler = MinMaxScaler()

# %%
def euclideanDistance(instance1, instance2, length):
    distance = 0
    for x in range(length):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)

def getNeighbors(trainingSet, testInstance, trainingTarget, k):
    distances = []
    length = len(testInstance)-1
    for x in range(len(trainingSet)):
        dist = euclideanDistance(testInstance, trainingSet[x], length)
        distances.append((trainingTarget[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors

def getResponse(neighbors):
    max = 0
    result = 0
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    for key, value in classVotes.items():
        if(value > max):
            result = key
            max = value
    return result
def getAccuracy(testSet, predictions):
    correct = 0
    for x in range(len(testSet)):
        if testSet[x][-1] == predictions[x]:
            correct += 1
    return (correct/float(len(testSet))) * 100.0

# %%
X = data.values
y = target.values
kf = KFold(n_splits=10)
k = 10

# KNN
fold = 0
accuracy_total = 0

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    X_train_scale = min_max_scaler.fit_transform(X_train)
    X_test_scale = min_max_scaler.transform(X_test)
    
    predictions=[]
    
    fold += 1
    print('KFold ' + str(fold))
    print('======================================')
          
    for i in range(len(X_test_scale)):
        neighbors = getNeighbors(X_train_scale, X_test_scale[i], y_train, k)
        result = getResponse(neighbors)
        predictions.append(result)
        
        print('> ' + str(i + 1) + ' predicted = ' + repr(result) + ', actual = ' + repr(y_test[i]))
        
    accuracy = accuracy_score(y_test, predictions)
    accuracy_total += accuracy
    
    print('---------------------------------------')
    print('KFold ' + str(fold) + ', Accuracy ' + str(accuracy))
    print('')

print('======================================')
print('Average Accuracy = ' + str(accuracy_total/fold))
print('======================================')
# Out:
# KFold 1
# ======================================
# > 1 predicted = 2, actual = 9
# > 2 predicted = 10, actual = 10
# > 3 predicted = 7, actual = 7
# > 4 predicted = 11, actual = 6
# > 5 predicted = 3, actual = 2
# > 6 predicted = 12, actual = 12
# > 7 predicted = 10, actual = 11
# > 8 predicted = 10, actual = 11
# > 9 predicted = 2, actual = 2
# > 10 predicted = 7, actual = 7
# > 11 predicted = 5, actual = 5
# > 12 predicted = 13, actual = 13
# > 13 predicted = 0, actual = 13
# > 14 predicted = 6, actual = 10
# > 15 predicted = 7, actual = 7
# > 16 predicted = 1, actual = 1
# > 17 predicted = 2, actual = 4
# > 18 predicted = 5, actual = 5
# > 19 predicted = 6, actual = 4
# > 20 predicted = 0, actual = 7
# > 21 predicted = 10, actual = 10
# > 22 predicted = 6, actual = 11
# > 23 predicted = 1, actual = 1
# > 24 predicted = 8, actual = 8
# > 25 predicted = 13, actual = 13
# > 26 predicted = 6, actual = 6
# > 27 predicted = 3, actual = 4
# > 28 predicted = 9, actual = 10
# > 29 predicted = 7, actual = 7
# > 30 predicted = 13, actual = 13
# > 31 predicted = 11, actual = 9
# > 32 predicted = 0, actual = 0
# > 33 predicted = 4, actual = 8
# > 34 predicted = 2, actual = 2
# > 35 predicted = 13, actual = 4
# > 36 predicted = 2, actual = 2
# > 37 predicted = 12, actual = 2
# > 38 predicted = 0, actual = 7
# > 39 predicted = 10, actual = 2
# > 40 predicted = 12, actual = 12
# > 41 predicted = 0, actual = 13
# > 42 predicted = 4, actual = 2
# > 43 predicted = 13, actual = 0
# > 44 predicted = 4, actual = 4
# > 45 predicted = 8, actual = 3
# > 46 predicted = 13, actual = 13
# > 47 predicted = 2, actual = 8
# > 48 predicted = 3, actual = 4
# > 49 predicted = 3, actual = 4
# > 50 predicted = 0, actual = 0
# > 51 predicted = 5, actual = 5
# > 52 predicted = 12, actual = 8
# > 53 predicted = 13, actual = 13
# > 54 predicted = 9, actual = 3
# > 55 predicted = 4, actual = 4
# > 56 predicted = 3, actual = 12
# > 57 predicted = 5, actual = 5
# > 58 predicted = 8, actual = 8
# > 59 predicted = 8, actual = 0
# > 60 predicted = 2, actual = 9
# > 61 predicted = 10, actual = 9
# > 62 predicted = 8, actual = 3
# > 63 predicted = 12, actual = 8
# > 64 predicted = 13, actual = 0
# > 65 predicted = 2, actual = 10
# > 66 predicted = 11, actual = 10
# > 67 predicted = 4, actual = 9
# > 68 predicted = 2, actual = 9
# > 69 predicted = 3, actual = 3
# > 70 predicted = 4, actual = 4
# ---------------------------------------
# KFold 1, Accuracy 0.44285714285714284
#
# KFold 2
# ======================================
# > 1 predicted = 7, actual = 7
# > 2 predicted = 12, actual = 3
# > 3 predicted = 4, actual = 2
# > 4 predicted = 12, actual = 12
# > 5 predicted = 6, actual = 6
# > 6 predicted = 1, actual = 7
# > 7 predicted = 13, actual = 0
# > 8 predicted = 0, actual = 0
# > 9 predicted = 10, actual = 2
# > 10 predicted = 5, actual = 13
# > 11 predicted = 1, actual = 7
# > 12 predicted = 4, actual = 11
# > 13 predicted = 9, actual = 4
# > 14 predicted = 8, actual = 8
# > 15 predicted = 2, actual = 11
# > 16 predicted = 5, actual = 5
# > 17 predicted = 3, actual = 9
# > 18 predicted = 3, actual = 3
# > 19 predicted = 10, actual = 9
# > 20 predicted = 10, actual = 10
# > 21 predicted = 0, actual = 13
# > 22 predicted = 5, actual = 5
# > 23 predicted = 9, actual = 9
# > 24 predicted = 5, actual = 5
# > 25 predicted = 11, actual = 13
# > 26 predicted = 6, actual = 11
# > 27 predicted = 12, actual = 12
# > 28 predicted = 2, actual = 2
# > 29 predicted = 11, actual = 6
# > 30 predicted = 5, actual = 5
# > 31 predicted = 1, actual = 7
# > 32 predicted = 2, actual = 2
# > 33 predicted = 1, actual = 1
# > 34 predicted = 1, actual = 7
# > 35 predicted = 3, actual = 9
# > 36 predicted = 10, actual = 13
# > 37 predicted = 4, actual = 6
# > 38 predicted = 0, actual = 0
# > 39 predicted = 1, actual = 7
# > 40 predicted = 12, actual = 4
# > 41 predicted = 2, actual = 13
# > 42 predicted = 12, actual = 8
# > 43 predicted = 10, actual = 10
# > 44 predicted = 6, actual = 10
# > 45 predicted = 6, actual = 6
# > 46 predicted = 5, actual = 3
# > 47 predicted = 4, actual = 3
# > 48 predicted = 8, actual = 8
# > 49 predicted = 6, actual = 11
# > 50 predicted = 7, actual = 7
# > 51 predicted = 4, actual = 11
# > 52 predicted = 11, actual = 6
# > 53 predicted = 3, actual = 3
# > 54 predicted = 12, actual = 12
# > 55 predicted = 0, actual = 0
# > 56 predicted = 5, actual = 5
# > 57 predicted = 4, actual = 0
# > 58 predicted = 10, actual = 11
# > 59 predicted = 12, actual = 8
# > 60 predicted = 11, actual = 11
# > 61 predicted = 1, actual = 1
# > 62 predicted = 8, actual = 8
# > 63 predicted = 13, actual = 1
# > 64 predicted = 8, actual = 8
# > 65 predicted = 3, actual = 3
# > 66 predicted = 13, actual = 13
# > 67 predicted = 3, actual = 9
# > 68 predicted = 11, actual = 11
# > 69 predicted = 0, actual = 11
# > 70 predicted = 10, actual = 0
# ---------------------------------------
# KFold 2, Accuracy 0.45714285714285713
#
# KFold 3
# ======================================
# > 1 predicted = 2, actual = 9
# > 2 predicted = 2, actual = 13
# > 3 predicted = 3, actual = 9
# > 4 predicted = 11, actual = 11
# > 5 predicted = 4, actual = 4
# > 6 predicted = 8, actual = 8
# > 7 predicted = 10, actual = 9
# > 8 predicted = 5, actual = 5
# > 9 predicted = 3, actual = 3
# > 10 predicted = 12, actual = 12
# > 11 predicted = 3, actual = 3
# > 12 predicted = 10, actual = 10
# > 13 predicted = 13, actual = 10
# > 14 predicted = 3, actual = 3
# > 15 predicted = 3, actual = 12
# > 16 predicted = 3, actual = 3
# > 17 predicted = 2, actual = 7
# > 18 predicted = 9, actual = 10
# > 19 predicted = 12, actual = 2
# > 20 predicted = 11, actual = 6
# > 21 predicted = 2, actual = 4
# > 22 predicted = 0, actual = 13
# > 23 predicted = 7, actual = 7
# > 24 predicted = 0, actual = 5
# > 25 predicted = 11, actual = 4
# > 26 predicted = 3, actual = 12
# > 27 predicted = 3, actual = 8
# > 28 predicted = 0, actual = 10
# > 29 predicted = 4, actual = 4
# > 30 predicted = 4, actual = 11
# > 31 predicted = 7, actual = 1
# > 32 predicted = 9, actual = 4
# > 33 predicted = 0, actual = 0
# > 34 predicted = 11, actual = 6
# > 35 predicted = 11, actual = 10
# > 36 predicted = 6, actual = 6
# > 37 predicted = 5, actual = 5
# > 38 predicted = 10, actual = 10
# > 39 predicted = 5, actual = 5
# > 40 predicted = 8, actual = 8
# > 41 predicted = 7, actual = 7
# > 42 predicted = 8, actual = 8
# > 43 predicted = 0, actual = 0
# > 44 predicted = 1, actual = 1
# > 45 predicted = 4, actual = 2
# > 46 predicted = 0, actual = 13
# > 47 predicted = 9, actual = 13
# > 48 predicted = 3, actual = 8
# > 49 predicted = 8, actual = 3
# > 50 predicted = 6, actual = 6
# > 51 predicted = 6, actual = 6
# > 52 predicted = 1, actual = 1
# > 53 predicted = 12, actual = 8
# > 54 predicted = 6, actual = 6
# > 55 predicted = 10, actual = 3
# > 56 predicted = 1, actual = 1
# > 57 predicted = 3, actual = 5
# > 58 predicted = 3, actual = 12
# > 59 predicted = 12, actual = 8
# > 60 predicted = 11, actual = 11
# > 61 predicted = 11, actual = 11
# > 62 predicted = 11, actual = 4
# > 63 predicted = 9, actual = 4
# > 64 predicted = 6, actual = 9
# > 65 predicted = 11, actual = 6
# > 66 predicted = 3, actual = 0
# > 67 predicted = 13, actual = 0
# > 68 predicted = 10, actual = 6
# > 69 predicted = 5, actual = 13
# > 70 predicted = 3, actual = 3
# ---------------------------------------
# KFold 3, Accuracy 0.42857142857142855
#
# KFold 4
# ======================================
# > 1 predicted = 10, actual = 6
# > 2 predicted = 5, actual = 3
# > 3 predicted = 5, actual = 5
# > 4 predicted = 4, actual = 9
# > 5 predicted = 5, actual = 13
# > 6 predicted = 11, actual = 10
# > 7 predicted = 10, actual = 0
# > 8 predicted = 9, actual = 6
# > 9 predicted = 8, actual = 8
# > 10 predicted = 5, actual = 9
# > 11 predicted = 2, actual = 12
# > 12 predicted = 5, actual = 5
# > 13 predicted = 2, actual = 3
# > 14 predicted = 0, actual = 0
# > 15 predicted = 6, actual = 6
# > 16 predicted = 10, actual = 13
# > 17 predicted = 5, actual = 5
# > 18 predicted = 0, actual = 1
# > 19 predicted = 12, actual = 12
# > 20 predicted = 3, actual = 2
# > 21 predicted = 3, actual = 2
# > 22 predicted = 2, actual = 3
# > 23 predicted = 6, actual = 6
# > 24 predicted = 10, actual = 9
# > 25 predicted = 10, actual = 11
# > 26 predicted = 6, actual = 11
# > 27 predicted = 1, actual = 0
# > 28 predicted = 12, actual = 12
# > 29 predicted = 1, actual = 1
# > 30 predicted = 3, actual = 2
# > 31 predicted = 5, actual = 5
# > 32 predicted = 3, actual = 3
# > 33 predicted = 10, actual = 10
# > 34 predicted = 8, actual = 8
# > 35 predicted = 7, actual = 7
# > 36 predicted = 7, actual = 7
# > 37 predicted = 7, actual = 7
# > 38 predicted = 6, actual = 9
# > 39 predicted = 11, actual = 13
# > 40 predicted = 1, actual = 1
# > 41 predicted = 6, actual = 2
# > 42 predicted = 7, actual = 7
# > 43 predicted = 5, actual = 5
# > 44 predicted = 10, actual = 3
# > 45 predicted = 11, actual = 0
# > 46 predicted = 13, actual = 13
# > 47 predicted = 12, actual = 12
# > 48 predicted = 6, actual = 4
# > 49 predicted = 2, actual = 2
# > 50 predicted = 13, actual = 0
# > 51 predicted = 9, actual = 11
# > 52 predicted = 10, actual = 11
# > 53 predicted = 5, actual = 13
# > 54 predicted = 5, actual = 2
# > 55 predicted = 0, actual = 0
# > 56 predicted = 8, actual = 12
# > 57 predicted = 5, actual = 5
# > 58 predicted = 9, actual = 10
# > 59 predicted = 5, actual = 5
# > 60 predicted = 0, actual = 1
# > 61 predicted = 0, actual = 13
# > 62 predicted = 13, actual = 13
# > 63 predicted = 1, actual = 7
# > 64 predicted = 7, actual = 1
# > 65 predicted = 4, actual = 11
# > 66 predicted = 12, actual = 3
# > 67 predicted = 4, actual = 4
# > 68 predicted = 0, actual = 13
# > 69 predicted = 3, actual = 3
# > 70 predicted = 7, actual = 7
# ---------------------------------------
# KFold 4, Accuracy 0.42857142857142855
#
# KFold 5
# ======================================
# > 1 predicted = 4, actual = 11
# > 2 predicted = 11, actual = 10
# > 3 predicted = 3, actual = 3
# > 4 predicted = 13, actual = 7
# > 5 predicted = 11, actual = 9
# > 6 predicted = 13, actual = 13
# > 7 predicted = 3, actual = 12
# > 8 predicted = 4, actual = 9
# > 9 predicted = 13, actual = 0
# > 10 predicted = 8, actual = 3
# > 11 predicted = 12, actual = 3
# > 12 predicted = 3, actual = 3
# > 13 predicted = 6, actual = 6
# > 14 predicted = 9, actual = 3
# > 15 predicted = 12, actual = 12
# > 16 predicted = 11, actual = 10
# > 17 predicted = 3, actual = 2
# > 18 predicted = 0, actual = 0
# > 19 predicted = 2, actual = 9
# > 20 predicted = 2, actual = 3
# > 21 predicted = 10, actual = 10
# > 22 predicted = 2, actual = 4
# > 23 predicted = 2, actual = 2
# > 24 predicted = 0, actual = 0
# > 25 predicted = 12, actual = 12
# > 26 predicted = 3, actual = 8
# > 27 predicted = 4, actual = 4
# > 28 predicted = 11, actual = 6
# > 29 predicted = 2, actual = 2
# > 30 predicted = 10, actual = 8
# > 31 predicted = 11, actual = 10
# > 32 predicted = 12, actual = 12
# > 33 predicted = 4, actual = 4
# > 34 predicted = 12, actual = 2
# > 35 predicted = 7, actual = 7
# > 36 predicted = 5, actual = 5
# > 37 predicted = 5, actual = 0
# > 38 predicted = 1, actual = 1
# > 39 predicted = 5, actual = 1
# > 40 predicted = 12, actual = 12
# > 41 predicted = 12, actual = 12
# > 42 predicted = 6, actual = 0
# > 43 predicted = 8, actual = 8
# > 44 predicted = 10, actual = 6
# > 45 predicted = 1, actual = 1
# > 46 predicted = 7, actual = 1
# > 47 predicted = 2, actual = 8
# > 48 predicted = 8, actual = 3
# > 49 predicted = 8, actual = 8
# > 50 predicted = 3, actual = 12
# > 51 predicted = 1, actual = 1
# > 52 predicted = 12, actual = 12
# > 53 predicted = 1, actual = 7
# > 54 predicted = 11, actual = 11
# > 55 predicted = 3, actual = 5
# > 56 predicted = 3, actual = 6
# > 57 predicted = 0, actual = 13
# > 58 predicted = 4, actual = 9
# > 59 predicted = 12, actual = 12
# > 60 predicted = 5, actual = 5
# > 61 predicted = 8, actual = 4
# > 62 predicted = 13, actual = 0
# > 63 predicted = 2, actual = 2
# > 64 predicted = 1, actual = 13
# > 65 predicted = 10, actual = 9
# > 66 predicted = 3, actual = 9
# > 67 predicted = 7, actual = 1
# > 68 predicted = 3, actual = 5
# > 69 predicted = 1, actual = 13
# > 70 predicted = 11, actual = 4
# ---------------------------------------
# KFold 5, Accuracy 0.4
#
# KFold 6
# ======================================
# > 1 predicted = 10, actual = 10
# > 2 predicted = 7, actual = 7
# > 3 predicted = 12, actual = 6
# > 4 predicted = 10, actual = 0
# > 5 predicted = 9, actual = 4
# > 6 predicted = 12, actual = 12
# > 7 predicted = 11, actual = 11
# > 8 predicted = 0, actual = 0
# > 9 predicted = 8, actual = 9
# > 10 predicted = 10, actual = 6
# > 11 predicted = 9, actual = 9
# > 12 predicted = 10, actual = 10
# > 13 predicted = 6, actual = 6
# > 14 predicted = 11, actual = 11
# > 15 predicted = 2, actual = 9
# > 16 predicted = 4, actual = 11
# > 17 predicted = 0, actual = 0
# > 18 predicted = 12, actual = 12
# > 19 predicted = 5, actual = 10
# > 20 predicted = 3, actual = 3
# > 21 predicted = 9, actual = 10
# > 22 predicted = 6, actual = 6
# > 23 predicted = 12, actual = 12
# > 24 predicted = 5, actual = 5
# > 25 predicted = 6, actual = 6
# > 26 predicted = 13, actual = 0
# > 27 predicted = 3, actual = 3
# > 28 predicted = 12, actual = 8
# > 29 predicted = 12, actual = 3
# > 30 predicted = 9, actual = 4
# > 31 predicted = 11, actual = 11
# > 32 predicted = 1, actual = 1
# > 33 predicted = 2, actual = 10
# > 34 predicted = 13, actual = 0
# > 35 predicted = 7, actual = 7
# > 36 predicted = 13, actual = 11
# > 37 predicted = 5, actual = 5
# > 38 predicted = 5, actual = 5
# > 39 predicted = 4, actual = 11
# > 40 predicted = 9, actual = 3
# > 41 predicted = 11, actual = 11
# > 42 predicted = 12, actual = 9
# > 43 predicted = 12, actual = 8
# > 44 predicted = 4, actual = 9
# > 45 predicted = 13, actual = 0
# > 46 predicted = 3, actual = 8
# > 47 predicted = 9, actual = 10
# > 48 predicted = 11, actual = 11
# > 49 predicted = 4, actual = 10
# > 50 predicted = 3, actual = 9
# > 51 predicted = 1, actual = 1
# > 52 predicted = 1, actual = 1
# > 53 predicted = 5, actual = 5
# > 54 predicted = 1, actual = 1
# > 55 predicted = 13, actual = 0
# > 56 predicted = 13, actual = 0
# > 57 predicted = 0, actual = 7
# > 58 predicted = 4, actual = 12
# > 59 predicted = 12, actual = 8
# > 60 predicted = 12, actual = 8
# > 61 predicted = 5, actual = 5
# > 62 predicted = 0, actual = 1
# > 63 predicted = 6, actual = 6
# > 64 predicted = 11, actual = 6
# > 65 predicted = 10, actual = 6
# > 66 predicted = 3, actual = 8
# > 67 predicted = 5, actual = 3
# > 68 predicted = 9, actual = 2
# > 69 predicted = 12, actual = 5
# > 70 predicted = 11, actual = 10
# ---------------------------------------
# KFold 6, Accuracy 0.42857142857142855
#
# KFold 7
# ======================================
# > 1 predicted = 11, actual = 11
# > 2 predicted = 0, actual = 0
# > 3 predicted = 2, actual = 2
# > 4 predicted = 11, actual = 11
# > 5 predicted = 5, actual = 5
# > 6 predicted = 12, actual = 12
# > 7 predicted = 9, actual = 11
# > 8 predicted = 0, actual = 13
# > 9 predicted = 12, actual = 2
# > 10 predicted = 3, actual = 5
# > 11 predicted = 7, actual = 7
# > 12 predicted = 11, actual = 11
# > 13 predicted = 7, actual = 7
# > 14 predicted = 12, actual = 8
# > 15 predicted = 9, actual = 2
# > 16 predicted = 12, actual = 12
# > 17 predicted = 3, actual = 4
# > 18 predicted = 4, actual = 8
# > 19 predicted = 0, actual = 0
# > 20 predicted = 8, actual = 8
# > 21 predicted = 8, actual = 12
# > 22 predicted = 12, actual = 2
# > 23 predicted = 6, actual = 6
# > 24 predicted = 10, actual = 10
# > 25 predicted = 0, actual = 13
# > 26 predicted = 1, actual = 7
# > 27 predicted = 12, actual = 4
# > 28 predicted = 4, actual = 4
# > 29 predicted = 1, actual = 1
# > 30 predicted = 4, actual = 4
# > 31 predicted = 12, actual = 8
# > 32 predicted = 10, actual = 10
# > 33 predicted = 7, actual = 1
# > 34 predicted = 12, actual = 12
# > 35 predicted = 7, actual = 7
# > 36 predicted = 13, actual = 0
# > 37 predicted = 3, actual = 9
# > 38 predicted = 13, actual = 13
# > 39 predicted = 8, actual = 12
# > 40 predicted = 1, actual = 1
# > 41 predicted = 5, actual = 5
# > 42 predicted = 2, actual = 12
# > 43 predicted = 8, actual = 8
# > 44 predicted = 13, actual = 2
# > 45 predicted = 3, actual = 3
# > 46 predicted = 12, actual = 2
# > 47 predicted = 3, actual = 3
# > 48 predicted = 1, actual = 1
# > 49 predicted = 3, actual = 3
# > 50 predicted = 12, actual = 12
# > 51 predicted = 1, actual = 1
# > 52 predicted = 1, actual = 1
# > 53 predicted = 5, actual = 5
# > 54 predicted = 13, actual = 2
# > 55 predicted = 5, actual = 5
# > 56 predicted = 10, actual = 9
# > 57 predicted = 1, actual = 1
# > 58 predicted = 9, actual = 10
# > 59 predicted = 1, actual = 7
# > 60 predicted = 1, actual = 1
# > 61 predicted = 11, actual = 10
# > 62 predicted = 2, actual = 10
# > 63 predicted = 0, actual = 2
# > 64 predicted = 1, actual = 1
# > 65 predicted = 2, actual = 2
# > 66 predicted = 13, actual = 13
# > 67 predicted = 7, actual = 7
# > 68 predicted = 12, actual = 12
# > 69 predicted = 8, actual = 8
# > 70 predicted = 5, actual = 5
# ---------------------------------------
# KFold 7, Accuracy 0.6
#
# KFold 8
# ======================================
# > 1 predicted = 7, actual = 7
# > 2 predicted = 11, actual = 9
# > 3 predicted = 6, actual = 6
# > 4 predicted = 13, actual = 9
# > 5 predicted = 2, actual = 10
# > 6 predicted = 4, actual = 9
# > 7 predicted = 11, actual = 11
# > 8 predicted = 12, actual = 12
# > 9 predicted = 0, actual = 0
# > 10 predicted = 5, actual = 5
# > 11 predicted = 7, actual = 7
# > 12 predicted = 11, actual = 10
# > 13 predicted = 11, actual = 11
# > 14 predicted = 3, actual = 9
# > 15 predicted = 9, actual = 9
# > 16 predicted = 7, actual = 7
# > 17 predicted = 10, actual = 13
# > 18 predicted = 0, actual = 13
# > 19 predicted = 11, actual = 6
# > 20 predicted = 8, actual = 8
# > 21 predicted = 0, actual = 2
# > 22 predicted = 3, actual = 3
# > 23 predicted = 1, actual = 1
# > 24 predicted = 6, actual = 11
# > 25 predicted = 5, actual = 5
# > 26 predicted = 3, actual = 2
# > 27 predicted = 3, actual = 9
# > 28 predicted = 12, actual = 0
# > 29 predicted = 4, actual = 4
# > 30 predicted = 11, actual = 4
# > 31 predicted = 11, actual = 11
# > 32 predicted = 6, actual = 6
# > 33 predicted = 5, actual = 2
# > 34 predicted = 3, actual = 8
# > 35 predicted = 13, actual = 13
# > 36 predicted = 5, actual = 7
# > 37 predicted = 2, actual = 2
# > 38 predicted = 3, actual = 9
# > 39 predicted = 3, actual = 3
# > 40 predicted = 1, actual = 1
# > 41 predicted = 7, actual = 1
# > 42 predicted = 4, actual = 10
# > 43 predicted = 9, actual = 10
# > 44 predicted = 6, actual = 6
# > 45 predicted = 13, actual = 9
# > 46 predicted = 6, actual = 6
# > 47 predicted = 12, actual = 12
# > 48 predicted = 7, actual = 7
# > 49 predicted = 0, actual = 4
# > 50 predicted = 13, actual = 2
# > 51 predicted = 4, actual = 4
# > 52 predicted = 0, actual = 13
# > 53 predicted = 5, actual = 5
# > 54 predicted = 1, actual = 1
# > 55 predicted = 1, actual = 7
# > 56 predicted = 2, actual = 10
# > 57 predicted = 9, actual = 6
# > 58 predicted = 10, actual = 9
# > 59 predicted = 6, actual = 6
# > 60 predicted = 8, actual = 0
# > 61 predicted = 2, actual = 5
# > 62 predicted = 0, actual = 13
# > 63 predicted = 2, actual = 6
# > 64 predicted = 1, actual = 1
# > 65 predicted = 3, actual = 7
# > 66 predicted = 0, actual = 2
# > 67 predicted = 4, actual = 9
# > 68 predicted = 6, actual = 6
# > 69 predicted = 8, actual = 8
# > 70 predicted = 10, actual = 2
# ---------------------------------------
# KFold 8, Accuracy 0.45714285714285713
#
# KFold 9
# ======================================
# > 1 predicted = 9, actual = 0
# > 2 predicted = 11, actual = 11
# > 3 predicted = 1, actual = 1
# > 4 predicted = 10, actual = 0
# > 5 predicted = 13, actual = 0
# > 6 predicted = 12, actual = 8
# > 7 predicted = 3, actual = 6
# > 8 predicted = 1, actual = 1
# > 9 predicted = 7, actual = 7
# > 10 predicted = 3, actual = 3
# > 11 predicted = 10, actual = 11
# > 12 predicted = 7, actual = 7
# > 13 predicted = 3, actual = 9
# > 14 predicted = 1, actual = 7
# > 15 predicted = 5, actual = 5
# > 16 predicted = 13, actual = 13
# > 17 predicted = 13, actual = 7
# > 18 predicted = 1, actual = 1
# > 19 predicted = 10, actual = 10
# > 20 predicted = 3, actual = 3
# > 21 predicted = 11, actual = 6
# > 22 predicted = 6, actual = 10
# > 23 predicted = 13, actual = 13
# > 24 predicted = 1, actual = 7
# > 25 predicted = 3, actual = 3
# > 26 predicted = 11, actual = 6
# > 27 predicted = 12, actual = 3
# > 28 predicted = 4, actual = 11
# > 29 predicted = 13, actual = 13
# > 30 predicted = 2, actual = 2
# > 31 predicted = 5, actual = 8
# > 32 predicted = 10, actual = 10
# > 33 predicted = 11, actual = 4
# > 34 predicted = 1, actual = 1
# > 35 predicted = 11, actual = 4
# > 36 predicted = 0, actual = 1
# > 37 predicted = 3, actual = 12
# > 38 predicted = 3, actual = 5
# > 39 predicted = 13, actual = 0
# > 40 predicted = 6, actual = 6
# > 41 predicted = 2, actual = 5
# > 42 predicted = 4, actual = 4
# > 43 predicted = 2, actual = 4
# > 44 predicted = 5, actual = 13
# > 45 predicted = 11, actual = 9
# > 46 predicted = 1, actual = 1
# > 47 predicted = 3, actual = 5
# > 48 predicted = 7, actual = 1
# > 49 predicted = 10, actual = 4
# > 50 predicted = 6, actual = 6
# > 51 predicted = 2, actual = 13
# > 52 predicted = 13, actual = 4
# > 53 predicted = 2, actual = 12
# > 54 predicted = 4, actual = 3
# > 55 predicted = 13, actual = 2
# > 56 predicted = 2, actual = 9
# > 57 predicted = 13, actual = 13
# > 58 predicted = 5, actual = 5
# > 59 predicted = 12, actual = 12
# > 60 predicted = 6, actual = 6
# > 61 predicted = 1, actual = 1
# > 62 predicted = 0, actual = 2
# > 63 predicted = 4, actual = 9
# > 64 predicted = 4, actual = 12
# > 65 predicted = 11, actual = 10
# > 66 predicted = 0, actual = 0
# > 67 predicted = 2, actual = 2
# > 68 predicted = 11, actual = 10
# > 69 predicted = 4, actual = 4
# > 70 predicted = 7, actual = 7
# ---------------------------------------
# KFold 9, Accuracy 0.42857142857142855
#
# KFold 10
# ======================================
# > 1 predicted = 12, actual = 8
# > 2 predicted = 13, actual = 0
# > 3 predicted = 12, actual = 4
# > 4 predicted = 9, actual = 11
# > 5 predicted = 7, actual = 1
# > 6 predicted = 5, actual = 5
# > 7 predicted = 6, actual = 11
# > 8 predicted = 12, actual = 12
# > 9 predicted = 3, actual = 4
# > 10 predicted = 11, actual = 11
# > 11 predicted = 11, actual = 10
# > 12 predicted = 10, actual = 4
# > 13 predicted = 12, actual = 12
# > 14 predicted = 9, actual = 6
# > 15 predicted = 8, actual = 8
# > 16 predicted = 10, actual = 2
# > 17 predicted = 12, actual = 3
# > 18 predicted = 7, actual = 7
# > 19 predicted = 0, actual = 0
# > 20 predicted = 2, actual = 12
# > 21 predicted = 3, actual = 9
# > 22 predicted = 2, actual = 12
# > 23 predicted = 4, actual = 4
# > 24 predicted = 5, actual = 5
# > 25 predicted = 7, actual = 7
# > 26 predicted = 3, actual = 2
# > 27 predicted = 13, actual = 13
# > 28 predicted = 4, actual = 4
# > 29 predicted = 12, actual = 12
# > 30 predicted = 3, actual = 3
# > 31 predicted = 12, actual = 8
# > 32 predicted = 7, actual = 1
# > 33 predicted = 6, actual = 10
# > 34 predicted = 10, actual = 13
# > 35 predicted = 6, actual = 6
# > 36 predicted = 0, actual = 0
# > 37 predicted = 10, actual = 11
# > 38 predicted = 2, actual = 2
# > 39 predicted = 3, actual = 3
# > 40 predicted = 4, actual = 4
# > 41 predicted = 11, actual = 11
# > 42 predicted = 10, actual = 10
# > 43 predicted = 4, actual = 2
# > 44 predicted = 3, actual = 12
# > 45 predicted = 4, actual = 4
# > 46 predicted = 12, actual = 8
# > 47 predicted = 2, actual = 13
# > 48 predicted = 2, actual = 3
# > 49 predicted = 10, actual = 11
# > 50 predicted = 7, actual = 7
# > 51 predicted = 0, actual = 13
# > 52 predicted = 3, actual = 9
# > 53 predicted = 5, actual = 5
# > 54 predicted = 3, actual = 8
# > 55 predicted = 3, actual = 8
# > 56 predicted = 5, actual = 5
# > 57 predicted = 8, actual = 12
# > 58 predicted = 10, actual = 10
# > 59 predicted = 6, actual = 11
# > 60 predicted = 6, actual = 6
# > 61 predicted = 3, actual = 4
# > 62 predicted = 12, actual = 12
# > 63 predicted = 2, actual = 0
# > 64 predicted = 9, actual = 10
# > 65 predicted = 13, actual = 13
# > 66 predicted = 12, actual = 8
# > 67 predicted = 10, actual = 2
# > 68 predicted = 9, actual = 9
# > 69 predicted = 1, actual = 1
# > 70 predicted = 11, actual = 11
# ---------------------------------------
# KFold 10, Accuracy 0.45714285714285713
#
# ======================================
# Average Accuracy = 0.45285714285714285
# ======================================
