# %%
# Import libraries
import math
import operator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

df = pd.read_csv("data fix baru 50.csv")
df = shuffle(df, random_state=1)
df.head()
# Out:
#       no  playlist  danceability  energy  key  loudness  mode  speechiness  \
# 681  682        13         0.590   0.737    1  0.878575     1       0.0384
# 626  627        12         0.589   0.797    1  0.889288     1       0.1500
# 329  330         6         0.816   0.579    1  0.872461     1       0.0867
# 620  621        12         0.500   0.847    1  0.922302     1       0.0417
# 399  400         7         0.411   0.449    1  0.618288     0       0.0318
#
#      acousticness  instrumentalness  liveness  valence     tempo  duration_ms
# 681       0.40400          0.000000    0.1080    0.877  0.614633            1
# 626       0.02890          0.000004    0.3830    0.232  0.473754            1
# 329       0.20300          0.000000    0.1270    0.430  0.555058            1
# 620       0.00125          0.000000    0.0875    0.716  0.582266            1
# 399       0.54800          0.609000    0.0814    0.579  0.665637            1

# %%
data = df.drop(columns=['no', 'playlist'])
data.head()
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 681         0.590   0.737    1  0.878575     1       0.0384       0.40400
# 626         0.589   0.797    1  0.889288     1       0.1500       0.02890
# 329         0.816   0.579    1  0.872461     1       0.0867       0.20300
# 620         0.500   0.847    1  0.922302     1       0.0417       0.00125
# 399         0.411   0.449    1  0.618288     0       0.0318       0.54800
#
#      instrumentalness  liveness  valence     tempo  duration_ms
# 681          0.000000    0.1080    0.877  0.614633            1
# 626          0.000004    0.3830    0.232  0.473754            1
# 329          0.000000    0.1270    0.430  0.555058            1
# 620          0.000000    0.0875    0.716  0.582266            1
# 399          0.609000    0.0814    0.579  0.665637            1

# %%
target = df.playlist
target.head()
# Out:
# 681    13
# 626    12
# 329     6
# 620    12
# 399     7
# Name: playlist, dtype: int64

# %%
min_max_scaler = MinMaxScaler()

# %%
def euclideanDistance(instance1, instance2, length):
    distance = 0
    for x in range(length):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)

def getNeighbors(trainingSet, testInstance, trainingTarget, k):
    distances = []
    length = len(testInstance)-1
    for x in range(len(trainingSet)):
        dist = euclideanDistance(testInstance, trainingSet[x], length)
        distances.append((trainingTarget[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors

def getResponse(neighbors):
    max = 0
    result = 0
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    for key, value in classVotes.items():
        if(value > max):
            result = key
            max = value
    return result
def getAccuracy(testSet, predictions):
    correct = 0
    for x in range(len(testSet)):
        if testSet[x][-1] == predictions[x]:
            correct += 1
    return (correct/float(len(testSet))) * 100.0

def cm_analysis(y_true, y_pred, labels, ymap=None, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)

# %%
X = data.values
y = target.values
kf = KFold(n_splits=10)
# pca = PCA(n_components=2)
k = 1

# KNN
fold = 0
accuracy_total = 0

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    X_train_scale = min_max_scaler.fit_transform(X_train)
    X_test_scale = min_max_scaler.transform(X_test)
    
#     pca.fit(X_train_scale)
#     X_train_pca = pca.fit_transform(X_train_scale)
#     X_test_pca = pca.fit_transform(X_test_scale)
    
#     index = np.hstack((train_index, test_index))
#     index = np.reshape(index, (len(index), 1))
#     X_pca = np.vstack((X_train_pca, X_test_pca))
#     Y_pca = np.hstack((y_train, y_test))
#     Y_pca = np.reshape(Y_pca, (len(Y_pca), 1))
#     data_pca = np.hstack((index, X_pca, Y_pca))
    
    predictions=[]
    
    fold += 1
#     np.savetxt('Klasifikasi Data/KNN MKNN tanpa PCA/Data PCA KNN Fold ' + str(fold) + '.csv', data_pca, delimiter=",")
    print('KFold ' + str(fold))
    print('======================================')
          
    for i in range(len(X_test_scale)):
        neighbors = getNeighbors(X_train_scale, X_test_scale[i], y_train, k)
        result = getResponse(neighbors)
        predictions.append(result)
        
        print('> ' + str(i + 1) + ' predicted = ' + repr(result) + ', actual = ' + repr(y_test[i]))
        
    accuracy = accuracy_score(y_test, predictions)
    accuracy_total += accuracy
    cm_analysis(y_test, predictions, target.unique().sort(), ymap=None, figsize=(10,10))
    plt.savefig('Klasifikasi Data/Gambar Confussion Matrix tanpa PCA/Confussion Matrix KNN Fold ' + str(fold) + '.jpg')
    
    print('---------------------------------------')
    print('KFold ' + str(fold) + ', Accuracy ' + str(accuracy))
    print('\n')
   # print('Klasifikasi Data/KNN MKNN tanpa PCA/Data PCA KNN Fold ' + str(fold) + '.csv')

print('======================================')
print('Average Accuracy = ' + str(accuracy_total/fold))
print('======================================')
print('\n')
# Out:
#  11
# > 94 predicted = 7, actual = 1
# > 95 predicted = 3, actual = 4
# > 96 predicted = 0, actual = 0
# > 97 predicted = 13, actual = 13
# > 98 predicted = 0, actual = 11
# > 99 predicted = 11, actual = 6
# > 100 predicted = 1, actual = 7
# > 101 predicted = 1, actual = 1
# > 102 predicted = 2, actual = 2
# > 103 predicted = 10, actual = 13
# > 104 predicted = 13, actual = 11
# > 105 predicted = 5, actual = 9
# > 106 predicted = 1, actual = 1
# > 107 predicted = 0, actual = 13
# > 108 predicted = 1, actual = 1
# > 109 predicted = 13, actual = 13
# > 110 predicted = 12, actual = 5
# > 111 predicted = 5, actual = 5
# > 112 predicted = 8, actual = 8
# > 113 predicted = 2, actual = 9
# > 114 predicted = 3, actual = 4
# > 115 predicted = 5, actual = 10
# > 116 predicted = 5, actual = 5
# > 117 predicted = 4, actual = 11
# > 118 predicted = 7, actual = 7
# > 119 predicted = 7, actual = 7
# > 120 predicted = 10, actual = 10
# > 121 predicted = 0, actual = 1
# > 122 predicted = 1, actual = 1
# > 123 predicted = 7, actual = 7
# > 124 predicted = 9, actual = 3
# > 125 predicted = 13, actual = 10
# > 126 predicted = 12, actual = 12
# > 127 predicted = 5, actual = 2
# > 128 predicted = 2, actual = 9
# > 129 predicted = 9, actual = 2
# > 130 predicted = 12, actual = 5
# > 131 predicted = 0, actual = 13
# > 132 predicted = 13, actual = 0
# > 133 predicted = 13, actual = 10
# > 134 predicted = 9, actual = 11
# > 135 predicted = 2, actual = 13
# > 136 predicted = 2, actual = 12
# > 137 predicted = 8, actual = 8
# > 138 predicted = 10, actual = 2
# > 139 predicted = 7, actual = 1
# > 140 predicted = 9, actual = 4
# > 141 predicted = 10, actual = 6
# > 142 predicted = 10, actual = 11
# > 143 predicted = 5, actual = 2
# > 144 predicted = 2, actual = 0
# > 145 predicted = 12, actual = 12
# > 146 predicted = 6, actual = 6
# > 147 predicted = 7, actual = 7
# > 148 predicted = 0, actual = 0
# > 149 predicted = 5, actual = 3
# > 150 predicted = 3, actual = 3
# > 151 predicted = 11, actual = 6
# > 152 predicted = 10, actual = 0
# > 153 predicted = 1, actual = 1
# > 154 predicted = 11, actual = 13
# > 155 predicted = 9, actual = 9
# > 156 predicted = 3, actual = 2
# > 157 predicted = 7, actual = 7
# > 158 predicted = 11, actual = 9
# > 159 predicted = 11, actual = 6
# > 160 predicted = 2, actual = 11
# > 161 predicted = 11, actual = 11
# > 162 predicted = 9, actual = 2
# > 163 predicted = 12, actual = 0
# > 164 predicted = 0, actual = 0
# > 165 predicted = 7, actual = 7
# > 166 predicted = 9, actual = 4
# > 167 predicted = 4, actual = 6
# > 168 predicted = 4, actual = 9
# > 169 predicted = 4, actual = 4
# > 170 predicted = 12, actual = 12
# > 171 predicted = 9, actual = 6
# > 172 predicted = 9, actual = 2
# > 173 predicted = 9, actual = 4
# > 174 predicted = 12, actual = 12
# > 175 predicted = 1, actual = 1
# > 176 predicted = 6, actual = 5
# > 177 predicted = 11, actual = 6
# > 178 predicted = 13, actual = 11
# > 179 predicted = 12, actual = 12
# > 180 predicted = 0, actual = 4
# > 181 predicted = 7, actual = 1
# > 182 predicted = 12, actual = 8
# > 183 predicted = 0, actual = 13
# > 184 predicted = 3, actual = 5
# > 185 predicted = 10, actual = 2
# > 186 predicted = 8, actual = 12
# > 187 predicted = 8, actual = 8
# > 188 predicted = 10, actual = 10
# > 189 predicted = 5, actual = 5
# > 190 predicted = 1, actual = 7
# > 191 predicted = 0, actual = 9
# > 192 predicted = 11, actual = 13
# > 193 predicted = 1, actual = 1
# > 194 predicted = 10, actual = 10
# > 195 predicted = 4, actual = 11
# > 196 predicted = 0, actual = 0
# > 197 predicted = 5, actual = 9
# > 198 predicted = 5, actual = 8
# > 199 predicted = 2, actual = 9
# > 200 predicted = 8, actual = 8
# > 201 predicted = 0, actual = 10
# > 202 predicted = 8, actual = 9
# > 203 predicted = 3, actual = 8
# > 204 predicted = 11, actual = 9
# > 205 predicted = 9, actual = 6
# > 206 predicted = 10, actual = 3
# > 207 predicted = 12, actual = 8
# > 208 predicted = 12, actual = 12
# > 209 predicted = 11, actual = 11
# > 210 predicted = 2, actual = 2
# > 211 predicted = 10, actual = 5
# > 212 predicted = 3, actual = 2
# > 213 predicted = 9, actual = 4
# > 214 predicted = 9, actual = 10
# > 215 predicted = 5, actual = 3
# > 216 predicted = 10, actual = 13
# > 217 predicted = 1, actual = 1
# > 218 predicted = 5, actual = 6
# > 219 predicted = 3, actual = 6
# > 220 predicted = 8, actual = 8
# > 221 predicted = 6, actual = 3
# > 222 predicted = 0, actual = 0
# > 223 predicted = 9, actual = 13
# > 224 predicted = 12, actual = 0
# > 225 predicted = 8, actual = 8
# > 226 predicted = 3, actual = 8
# > 227 predicted = 7, actual = 7
# > 228 predicted = 12, actual = 12
# > 229 predicted = 3, actual = 3
# > 230 predicted = 3, actual = 7
# > 231 predicted = 13, actual = 6
# > 232 predicted = 7, actual = 7
# > 233 predicted = 4, actual = 13
# > 234 predicted = 5, actual = 8
# ---------------------------------------
# KFold 1, Accuracy 0.3717948717948718
#
#
# KFold 2
# ======================================
# > 1 predicted = 8, actual = 8
# > 2 predicted = 12, actual = 12
# > 3 predicted = 9, actual = 4
# > 4 predicted = 8, actual = 3
# > 5 predicted = 13, actual = 0
# > 6 predicted = 1, actual = 7
# > 7 predicted = 13, actual = 10
# > 8 predicted = 1, actual = 7
# > 9 predicted = 0, actual = 0
# > 10 predicted = 13, actual = 13
# > 11 predicted = 7, actual = 7
# > 12 predicted = 7, actual = 7
# > 13 predicted = 10, actual = 8
# > 14 predicted = 0, actual = 0
# > 15 predicted = 9, actual = 5
# > 16 predicted = 13, actual = 11
# > 17 predicted = 6, actual = 5
# > 18 predicted = 7, actual = 7
# > 19 predicted = 10, actual = 11
# > 20 predicted = 3, actual = 3
# > 21 predicted = 10, actual = 1
# > 22 predicted = 2, actual = 2
# > 23 predicted = 13, actual = 0
# > 24 predicted = 0, actual = 0
# > 25 predicted = 13, actual = 0
# > 26 predicted = 3, actual = 8
# > 27 predicted = 0, actual = 1
# > 28 predicted = 3, actual = 10
# > 29 predicted = 4, actual = 4
# > 30 predicted = 6, actual = 6
# > 31 predicted = 3, actual = 12
# > 32 predicted = 9, actual = 9
# > 33 predicted = 10, actual = 5
# > 34 predicted = 9, actual = 6
# > 35 predicted = 8, actual = 8
# > 36 predicted = 3, actual = 3
# > 37 predicted = 7, actual = 7
# > 38 predicted = 12, actual = 12
# > 39 predicted = 5, actual = 5
# > 40 predicted = 13, actual = 10
# > 41 predicted = 9, actual = 9
# > 42 predicted = 8, actual = 4
# > 43 predicted = 0, actual = 13
# > 44 predicted = 1, actual = 1
# > 45 predicted = 9, actual = 10
# > 46 predicted = 13, actual = 0
# > 47 predicted = 3, actual = 2
# > 48 predicted = 10, actual = 9
# > 49 predicted = 11, actual = 11
# > 50 predicted = 8, actual = 5
# > 51 predicted = 12, actual = 12
# > 52 predicted = 8, actual = 8
# > 53 predicted = 9, actual = 7
# > 54 predicted = 12, actual = 3
# > 55 predicted = 3, actual = 8
# > 56 predicted = 1, actual = 7
# > 57 predicted = 6, actual = 6
# > 58 predicted = 10, actual = 10
# > 59 predicted = 10, actual = 7
# > 60 predicted = 12, actual = 8
# > 61 predicted = 8, actual = 3
# > 62 predicted = 8, actual = 13
# > 63 predicted = 12, actual = 8
# > 64 predicted = 4, actual = 13
# > 65 predicted = 0, actual = 10
# > 66 predicted = 2, actual = 2
# > 67 predicted = 1, actual = 1
# > 68 predicted = 13, actual = 9
# > 69 predicted = 2, actual = 11
# > 70 predicted = 6, actual = 6
# > 71 predicted = 1, actual = 1
# > 72 predicted = 8, actual = 7
# > 73 predicted = 13, actual = 2
# > 74 predicted = 12, actual = 3
# > 75 predicted = 2, actual = 2
# > 76 predicted = 11, actual = 10
# > 77 predicted = 12, actual = 8
# > 78 predicted = 13, actual = 8
# > 79 predicted = 9, actual = 10
# > 80 predicted = 2, actual = 2
# > 81 predicted = 4, actual = 13
# > 82 predicted = 7, actual = 0
# > 83 predicted = 11, actual = 5
# > 84 predicted = 10, actual = 10
# > 85 predicted = 10, actual = 4
# > 86 predicted = 8, actual = 8
# > 87 predicted = 7, actual = 1
# > 88 predicted = 4, actual = 4
# > 89 predicted = 13, actual = 12
# > 90 predicted = 9, actual = 11
# > 91 predicted = 3, actual = 4
# > 92 predicted = 6, actual = 9
# > 93 predicted = 8, actual = 5
# > 94 predicted = 2, actual = 10
# > 95 predicted = 0, actual = 0
# > 96 predicted = 13, actual = 13
# > 97 predicted = 7, actual = 4
# > 98 predicted = 0, actual = 0
# > 99 predicted = 0, actual = 13
# > 100 predicted = 9, actual = 4
# > 101 predicted = 0, actual = 0
# > 102 predicted = 2, actual = 3
# > 103 predicted = 1, actual = 13
# > 104 predicted = 9, actual = 5
# > 105 predicted = 5, actual = 10
# > 106 predicted = 7, actual = 13
# > 107 predicted = 11, actual = 10
# > 108 predicted = 6, actual = 6
# > 109 predicted = 5, actual = 5
# > 110 predicted = 12, actual = 12
# > 111 predicted = 9, actual = 10
# > 112 predicted = 10, actual = 10
# > 113 predicted = 7, actual = 7
# > 114 predicted = 1, actual = 1
# > 115 predicted = 2, actual = 4
# > 116 predicted = 5, actual = 5
# > 117 predicted = 13, actual = 6
# > 118 predicted = 9, actual = 5
# > 119 predicted = 12, actual = 8
# > 120 predicted = 2, actual = 2
# > 121 predicted = 3, actual = 2
# > 122 predicted = 0, actual = 13
# > 123 predicted = 0, actual = 13
# > 124 predicted = 12, actual = 8
# > 125 predicted = 13, actual = 0
# > 126 predicted = 3, actual = 9
# > 127 predicted = 7, actual = 7
# > 128 predicted = 4, actual = 4
# > 129 predicted = 2, actual = 4
# > 130 predicted = 4, actual = 4
# > 131 predicted = 3, actual = 4
# > 132 predicted = 8, actual = 8
# > 133 predicted = 6, actual = 9
# > 134 predicted = 5, actual = 10
# > 135 predicted = 7, actual = 7
# > 136 predicted = 4, actual = 4
# > 137 predicted = 9, actual = 2
# > 138 predicted = 9, actual = 11
# > 139 predicted = 12, actual = 3
# > 140 predicted = 5, actual = 12
# > 141 predicted = 10, actual = 11
# > 142 predicted = 11, actual = 11
# > 143 predicted = 7, actual = 4
# > 144 predicted = 1, actual = 1
# > 145 predicted = 2, actual = 9
# > 146 predicted = 5, actual = 5
# > 147 predicted = 9, actual = 11
# > 148 predicted = 1, actual = 1
# > 149 predicted = 12, actual = 8
# > 150 predicted = 3, actual = 7
# > 151 predicted = 7, actual = 1
# > 152 predicted = 5, actual = 9
# > 153 predicted = 12, actual = 12
# > 154 predicted = 7, actual = 7
# > 155 predicted = 0, actual = 0
# > 156 predicted = 5, actual = 6
# > 157 predicted = 9, actual = 11
# > 158 predicted = 4, actual = 2
# > 159 predicted = 3, actual = 11
# > 160 predicted = 3, actual = 0
# > 161 predicted = 12, actual = 8
# > 162 predicted = 13, actual = 0
# > 163 predicted = 1, actual = 1
# > 164 predicted = 11, actual = 6
# > 165 predicted = 1, actual = 1
# > 166 predicted = 5, actual = 3
# > 167 predicted = 3, actual = 3
# > 168 predicted = 10, actual = 13
# > 169 predicted = 11, actual = 11
# > 170 predicted = 7, actual = 10
# > 171 predicted = 3, actual = 9
# > 172 predicted = 1, actual = 1
# > 173 predicted = 10, actual = 10
# > 174 predicted = 7, actual = 7
# > 175 predicted = 12, actual = 12
# > 176 predicted = 2, actual = 2
# > 177 predicted = 0, actual = 13
# > 178 predicted = 8, actual = 8
# > 179 predicted = 11, actual = 6
# > 180 predicted = 7, actual = 7
# > 181 predicted = 0, actual = 0
# > 182 predicted = 8, actual = 12
# > 183 predicted = 10, actual = 13
# > 184 predicted = 5, actual = 13
# > 185 predicted = 3, actual = 10
# > 186 predicted = 3, actual = 11
# > 187 predicted = 9, actual = 4
# > 188 predicted = 2, actual = 2
# > 189 predicted = 6, actual = 11
# > 190 predicted = 11, actual = 6
# > 191 predicted = 9, actual = 8
# > 192 predicted = 5, actual = 2
# > 193 predicted = 12, actual = 12
# > 194 predicted = 0, actual = 0
# > 195 predicted = 4, actual = 13
# > 196 predicted = 7, actual = 1
# > 197 predicted = 8, actual = 8
# > 198 predicted = 9, actual = 4
# > 199 predicted = 9, actual = 6
# > 200 predicted = 7, actual = 2
# > 201 predicted = 7, actual = 7
# > 202 predicted = 9, actual = 3
# > 203 predicted = 13, actual = 11
# > 204 predicted = 11, actual = 3
# > 205 predicted = 13, actual = 5
# > 206 predicted = 2, actual = 8
# > 207 predicted = 12, actual = 12
# > 208 predicted = 11, actual = 2
# > 209 predicted = 13, actual = 2
# > 210 predicted = 12, actual = 12
# > 211 predicted = 1, actual = 1
# > 212 predicted = 9, actual = 4
# > 213 predicted = 3, actual = 2
# > 214 predicted = 2, actual = 5
# > 215 predicted = 8, actual = 5
# > 216 predicted = 3, actual = 5
# > 217 predicted = 3, actual = 6
# > 218 predicted = 2, actual = 5
# > 219 predicted = 6, actual = 3
# > 220 predicted = 12, actual = 2
# > 221 predicted = 11, actual = 6
# > 222 predicted = 8, actual = 8
# > 223 predicted = 13, actual = 13
# > 224 predicted = 8, actual = 12
# > 225 predicted = 7, actual = 4
# > 226 predicted = 7, actual = 4
# > 227 predicted = 2, actual = 3
# > 228 predicted = 4, actual = 6
# > 229 predicted = 2, actual = 4
# > 230 predicted = 3, actual = 9
# > 231 predicted = 10, actual = 10
# > 232 predicted = 10, actual = 5
# > 233 predicted = 2, actual = 3
# ---------------------------------------
# KFold 2, Accuracy 0.3562231759656652
#
#
# KFold 3
# ======================================
# > 1 predicted = 4, actual = 3
# > 2 predicted = 5, actual = 9
# > 3 predicted = 8, actual = 3
# > 4 predicted = 6, actual = 3
# > 5 predicted = 4, actual = 11
# > 6 predicted = 4, actual = 4
# > 7 predicted = 2, actual = 3
# > 8 predicted = 10, actual = 6
# > 9 predicted = 10, actual = 6
# > 10 predicted = 2, actual = 2
# > 11 predicted = 3, actual = 3
# > 12 predicted = 6, actual = 4
# > 13 predicted = 13, actual = 4
# > 14 predicted = 7, actual = 3
# > 15 predicted = 4, actual = 4
# > 16 predicted = 8, actual = 5
# > 17 predicted = 11, actual = 11
# > 18 predicted = 12, actual = 12
# > 19 predicted = 3, actual = 10
# > 20 predicted = 2, actual = 10
# > 21 predicted = 1, actual = 1
# > 22 predicted = 4, actual = 7
# > 23 predicted = 9, actual = 11
# > 24 predicted = 4, actual = 3
# > 25 predicted = 12, actual = 12
# > 26 predicted = 1, actual = 1
# > 27 predicted = 11, actual = 4
# > 28 predicted = 11, actual = 10
# > 29 predicted = 3, actual = 5
# > 30 predicted = 2, actual = 10
# > 31 predicted = 3, actual = 8
# > 32 predicted = 9, actual = 10
# > 33 predicted = 6, actual = 4
# > 34 predicted = 2, actual = 2
# > 35 predicted = 8, actual = 5
# > 36 predicted = 2, actual = 12
# > 37 predicted = 8, actual = 8
# > 38 predicted = 1, actual = 7
# > 39 predicted = 13, actual = 13
# > 40 predicted = 1, actual = 1
# > 41 predicted = 7, actual = 4
# > 42 predicted = 7, actual = 7
# > 43 predicted = 13, actual = 13
# > 44 predicted = 10, actual = 13
# > 45 predicted = 10, actual = 3
# > 46 predicted = 10, actual = 5
# > 47 predicted = 2, actual = 9
# > 48 predicted = 6, actual = 9
# > 49 predicted = 5, actual = 5
# > 50 predicted = 13, actual = 0
# > 51 predicted = 9, actual = 2
# > 52 predicted = 13, actual = 0
# > 53 predicted = 13, actual = 4
# > 54 predicted = 2, actual = 3
# > 55 predicted = 7, actual = 10
# > 56 predicted = 10, actual = 0
# > 57 predicted = 9, actual = 2
# > 58 predicted = 9, actual = 2
# > 59 predicted = 5, actual = 6
# > 60 predicted = 2, actual = 4
# > 61 predicted = 0, actual = 0
# > 62 predicted = 6, actual = 5
# > 63 predicted = 1, actual = 1
# > 64 predicted = 12, actual = 12
# > 65 predicted = 13, actual = 13
# > 66 predicted = 0, actual = 0
# > 67 predicted = 13, actual = 13
# > 68 predicted = 6, actual = 9
# > 69 predicted = 1, actual = 1
# > 70 predicted = 8, actual = 8
# > 71 predicted = 2, actual = 7
# > 72 predicted = 12, actual = 12
# > 73 predicted = 5, actual = 6
# > 74 predicted = 4, actual = 9
# > 75 predicted = 4, actual = 4
# > 76 predicted = 11, actual = 9
# > 77 predicted = 8, actual = 8
# > 78 predicted = 5, actual = 12
# > 79 predicted = 6, actual = 6
# > 80 predicted = 2, actual = 12
# > 81 predicted = 2, actual = 4
# > 82 predicted = 8, actual = 12
# > 83 predicted = 10, actual = 5
# > 84 predicted = 10, actual = 0
# > 85 predicted = 12, actual = 8
# > 86 predicted = 10, actual = 6
# > 87 predicted = 3, actual = 3
# > 88 predicted = 13, actual = 9
# > 89 predicted = 2, actual = 2
# > 90 predicted = 7, actual = 10
# > 91 predicted = 2, actual = 4
# > 92 predicted = 13, actual = 13
# > 93 predicted = 13, actual = 13
# > 94 predicted = 5, actual = 12
# > 95 predicted = 6, actual = 10
# > 96 predicted = 6, actual = 11
# > 97 predicted = 4, actual = 4
# > 98 predicted = 8, actual = 8
# > 99 predicted = 4, actual = 6
# > 100 predicted = 7, actual = 3
# > 101 predicted = 10, actual = 11
# > 102 predicted = 9, actual = 11
# > 103 predicted = 5, actual = 9
# > 104 predicted = 5, actual = 5
# > 105 predicted = 0, actual = 0
# > 106 predicted = 12, actual = 3
# > 107 predicted = 8, actual = 8
# > 108 predicted = 3, actual = 12
# > 109 predicted = 6, actual = 11
# > 110 predicted = 4, actual = 3
# > 111 predicted = 3, actual = 6
# > 112 predicted = 7, actual = 3
# > 113 predicted = 4, actual = 9
# > 114 predicted = 0, actual = 12
# > 115 predicted = 9, actual = 5
# > 116 predicted = 12, actual = 9
# > 117 predicted = 2, actual = 2
# > 118 predicted = 12, actual = 6
# > 119 predicted = 10, actual = 11
# > 120 predicted = 4, actual = 9
# > 121 predicted = 9, actual = 11
# > 122 predicted = 0, actual = 3
# > 123 predicted = 13, actual = 2
# > 124 predicted = 12, actual = 8
# > 125 predicted = 2, actual = 9
# > 126 predicted = 3, actual = 3
# > 127 predicted = 8, actual = 12
# > 128 predicted = 10, actual = 0
# > 129 predicted = 5, actual = 5
# > 130 predicted = 1, actual = 1
# > 131 predicted = 4, actual = 4
# > 132 predicted = 10, actual = 13
# > 133 predicted = 2, actual = 11
# > 134 predicted = 0, actual = 10
# > 135 predicted = 2, actual = 13
# > 136 predicted = 2, actual = 10
# > 137 predicted = 11, actual = 13
# > 138 predicted = 9, actual = 6
# > 139 predicted = 1, actual = 1
# > 140 predicted = 7, actual = 1
# > 141 predicted = 5, actual = 5
# > 142 predicted = 0, actual = 2
# > 143 predicted = 3, actual = 13
# > 144 predicted = 6, actual = 10
# > 145 predicted = 7, actual = 13
# > 146 predicted = 9, actual = 9
# > 147 predicted = 9, actual = 11
# > 148 predicted = 4, actual = 9
# > 149 predicted = 5, actual = 5
# > 150 predicted = 4, actual = 7
# > 151 predicted = 5, actual = 6
# > 152 predicted = 7, actual = 3
# > 153 predicted = 6, actual = 6
# > 154 predicted = 4, actual = 3
# > 155 predicted = 10, actual = 11
# > 156 predicted = 3, actual = 6
# > 157 predicted = 7, actual = 4
# > 158 predicted = 1, actual = 1
# > 159 predicted = 12, actual = 12
# > 160 predicted = 12, actual = 8
# > 161 predicted = 5, actual = 5
# > 162 predicted = 12, actual = 3
# > 163 predicted = 6, actual = 11
# > 164 predicted = 11, actual = 13
# > 165 predicted = 4, actual = 3
# > 166 predicted = 7, actual = 7
# > 167 predicted = 0, actual = 7
# > 168 predicted = 11, actual = 5
# > 169 predicted = 9, actual = 2
# > 170 predicted = 9, actual = 0
# > 171 predicted = 12, actual = 12
# > 172 predicted = 2, actual = 5
# > 173 predicted = 6, actual = 9
# > 174 predicted = 1, actual = 7
# > 175 predicted = 4, actual = 0
# > 176 predicted = 8, actual = 3
# > 177 predicted = 1, actual = 1
# > 178 predicted = 8, actual = 0
# > 179 predicted = 11, actual = 9
# > 180 predicted = 8, actual = 5
# > 181 predicted = 3, actual = 12
# > 182 predicted = 11, actual = 6
# > 183 predicted = 13, actual = 0
# > 184 predicted = 13, actual = 11
# > 185 predicted = 0, actual = 0
# > 186 predicted = 11, actual = 9
# > 187 predicted = 6, actual = 10
# > 188 predicted = 13, actual = 13
# > 189 predicted = 8, actual = 11
# > 190 predicted = 6, actual = 9
# > 191 predicted = 7, actual = 7
# > 192 predicted = 1, actual = 1
# > 193 predicted = 11, actual = 10
# > 194 predicted = 4, actual = 9
# > 195 predicted = 8, actual = 12
# > 196 predicted = 12, actual = 8
# > 197 predicted = 0, actual = 12
# > 198 predicted = 4, actual = 13
# > 199 predicted = 3, actual = 5
# > 200 predicted = 6, actual = 4
# > 201 predicted = 10, actual = 6
# > 202 predicted = 7, actual = 10
# > 203 predicted = 11, actual = 6
# > 204 predicted = 2, actual = 10
# > 205 predicted = 6, actual = 6
# > 206 predicted = 0, actual = 0
# > 207 predicted = 10, actual = 7
# > 208 predicted = 3, actual = 2
# > 209 predicted = 1, actual = 1
# > 210 predicted = 0, actual = 9
# > 211 predicted = 8, actual = 10
# > 212 predicted = 4, actual = 4
# > 213 predicted = 11, actual = 11
# > 214 predicted = 6, actual = 11
# > 215 predicted = 7, actual = 7
# > 216 predicted = 2, actual = 13
# > 217 predicted = 4, actual = 9
# > 218 predicted = 5, actual = 5
# > 219 predicted = 2, actual = 9
# > 220 predicted = 7, actual = 7
# > 221 predicted = 12, actual = 5
# > 222 predicted = 0, actual = 5
# > 223 predicted = 8, actual = 3
# > 224 predicted = 10, actual = 5
# > 225 predicted = 7, actual = 7
# > 226 predicted = 6, actual = 10
# > 227 predicted = 6, actual = 11
# > 228 predicted = 9, actual = 2
# > 229 predicted = 2, actual = 2
# > 230 predicted = 0, actual = 12
# > 231 predicted = 1, actual = 1
# > 232 predicted = 7, actual = 4
# > 233 predicted = 13, actual = 0
# ---------------------------------------
# KFold 3, Accuracy 0.2918454935622318
#
#
# ======================================
# Average Accuracy = 0.3399545137742563
# ======================================
